# %%
import pandas as pd
import json
from collections import defaultdict
from tqdm import tqdm
import random
from copy import deepcopy
import re


SPIECE_UNDERLINE = '▁'
def is_whitespace(c):
    if c == " " or c == "\t" or c == "\r" or c == "\n" or ord(c) == 0x202F or c == SPIECE_UNDERLINE:
        return True
    return False

def whitespace_tokenize(text):
    """Runs basic whitespace cleaning and splitting on a peice of text."""
    text = text.strip()
    if not text:
        return []
    tokens = text.split()
    return tokens
    
def _is_chinese_char(cp):
    if ((cp >= 0x4E00 and cp <= 0x9FFF) or  #
            (cp >= 0x3400 and cp <= 0x4DBF) or  #
            (cp >= 0x20000 and cp <= 0x2A6DF) or  #
            (cp >= 0x2A700 and cp <= 0x2B73F) or  #
            (cp >= 0x2B740 and cp <= 0x2B81F) or  #
            (cp >= 0x2B820 and cp <= 0x2CEAF) or
            (cp >= 0xF900 and cp <= 0xFAFF) or  #
            (cp >= 0x2F800 and cp <= 0x2FA1F)):  #
        return True

    return False

def is_fuhao(c):
    if c == '。' or c == '，' or c == '！' or c == '？' or c == '；' or c == '、' or c == '：' or c == '（' or c == '）' \
            or c == '－' or c == '~' or c == '「' or c == '《' or c == '》' or c == ',' or c == '」' or c == '"' or c == '“' or c == '”' \
            or c == '$' or c == '『' or c == '』' or c == '—' or c == ';' or c == '。' or c == '(' or c == ')' or c == '-' or c == '～' or c == '。' \
            or c == '‘' or c == '’':
        return True
    return False
    
def _tokenize_chinese_chars(text):
    """Adds whitespace around any CJK character."""
    output = []
    for char in text:
        cp = ord(char)
        if _is_chinese_char(cp) or is_fuhao(char):
            if len(output) > 0 and output[-1] != SPIECE_UNDERLINE:
                output.append(SPIECE_UNDERLINE)
            output.append(char)
            output.append(SPIECE_UNDERLINE)
        else:
            output.append(char)
    return "".join(output)

def read_kg(kg_path,kg):
    #'/home/xhsun/NLP/KGQA/KG/kgCLUE/Knowledge.txt'
    with open(kg_path) as f:
        lines=f.readlines()

    print('The number of triples: {}'.format(len(lines)))

    sub_map = defaultdict(set)#每一个头实体作为key，对应的所有一跳路径内的(关系，尾实体)作为value
    # so_map=defaultdict(set)#每一对(头实体，尾实体)作为key，对应的所有一跳的关系作为value
    sp_map=defaultdict(set)#每一个（头实体，关系）作为key，对应的仅能有一个答案

    alias_map=defaultdict(set)
    ent_to_relations=defaultdict(set)
    bad_line=0
    spliter='|||' if kg=='nlpcc' else '\t'
    for i in tqdm(range(len(lines))):
        line=lines[i]
        l = line.strip().split(spliter)
        s = l[0].strip()
        p = l[1].strip()
        o = l[2].strip()
        if s=='' or p=='' or o=='':
            bad_line+=1
            continue
        sub_map[s].add((p, o))
    #     so_map[(s,o)].add(p)
        sp_map[(s,p)].add(o)

        ent_to_relations[s].add(p)

        entity_mention=s
        if kg.lower()=='kgclue' and ('（' in s and '）' in s):
            entity_mention=s.split('（')[0]
            alias_map[entity_mention].add(s)
        if kg.lower()=='nlpcc' and ('(' in s and ')' in s):
            entity_mention=s.split('(')[0]
            alias_map[entity_mention].add(s)

        if p in ['别名','中文名','英文名','昵称','中文名称','英文名称','别称','全称','原名']:
            alias_map[entity_mention].add(o)
    return alias_map,sub_map

# %%
alias_map,sub_map=read_kg('/home/xhsun/NLP/KGQA/KG/kgCLUE/Knowledge.txt',kg='kgclue')
# Out:
# The number of triples: 22883549
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 22883549/22883549 [01:05<00:00, 348867.28it/s]

# %%
def read_data(data_path):
    with open(data_path) as f:
        lines=f.readlines()
    data=[]
    for line in lines:
        data.append(json.loads(line))
    print("原始数据有{}个样本".format(len(data)))
    return data

examples=read_data('../../data/kgclue/test_public.json')
# Out:
# 原始数据有2000个样本

# %%
def fun(examples,sub_map):
    ner_examples=[]
    for example in examples:
        triple=example['answer']
        head,rel,tail=triple.split('|||')
        head=head.strip()
        try:
            assert head in sub_map
            relations=[r for r,t in sub_map[head]]
            example.update({"relations":relations})
            ner_examples.append(example)
        except:
            print(head,example)
            #raise Exception("check")
            continue
        
    ner_examples2=[]
    for example in ner_examples:
        triple=example['answer']
        #head,rel,tail=triple.split('|||')
        relations=example['relations']
        tag='O'
        for rel in relations:
            found_each_rel=False
            for ner_tag,tag_attrs in tag2attrs.items():
                if rel in tag_attrs:
                    found_each_rel=True
                    break
            if found_each_rel:
                tag=ner_tag
                break
        example.update({'tag':tag})
        ner_examples2.append(example)
    
    outputs=[]
    filtered_count=0
    for example in ner_examples2:
        question=example['question']
        triple=example['answer']
        tag=example['tag']
        head=triple.split('|||')[0].strip()
        if '（' in head and '）' in head:
            head=head.split('（')[0]
        if head not in question:
            filtered_count+=1
            continue
        assert head in question
        for tag_ner in tag2attrs.keys():
            input_=question+'。这个句子中有哪些属于{}？'.format(tag_ner)
            output_=head if tag_ner==tag else "空实体"
            outputs.append([input_,output_])
        if tag=='O':
            outputs.append([question+'。这个句子中有哪些属于{}？'.format('普通实体'),head])
        else:
            outputs.append([question+'。这个句子中有哪些属于{}？'.format('普通实体'),'空实体'])
    print(filtered_count)
    return outputs

# %%
outputs=fun(examples,sub_map)
# Out:
# 0

# %%
len(outputs)
# Out:
# 22000

# %%
outputs[:1000]
# Out:
# [['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道长江武汉航道局管多少个地方吗？。这个句子中有哪些属于普通实体？', '长江武汉航道局'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于人名？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于音乐？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于节日？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于地名？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于书籍？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于游戏？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于疾病？', '空实体'],
#  ['东瓯王发生的主要事件是什么？。这个句子中有哪些属于普通实体？', '东瓯王'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于人名？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于音乐？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于节日？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于地名？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于书籍？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于游戏？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于疾病？', '空实体'],
#  ['山西省铸造新工艺工程技术研究中心是什么的管辖的啊？。这个句子中有哪些属于普通实体？', '山西省铸造新工艺工程技术研究中心'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于人名？', '丘堤'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道谁是丘堤的儿媳吗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于人名？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于音乐？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于节日？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于地名？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于书籍？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于游戏？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于疾病？', '空实体'],
#  ['国民军参与过什么战争？。这个句子中有哪些属于普通实体？', '国民军'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道诺基亚lumia1320的主屏尺寸是多少吗？。这个句子中有哪些属于普通实体？', '诺基亚lumia1320'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于人名？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于节日？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于地名？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你什么时候参加的执业兽医资格考试啊？。这个句子中有哪些属于普通实体？', '执业兽医资格考试'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道2007年度北京流行音乐典礼是哪种类型的奖项吗。这个句子中有哪些属于普通实体？', '2007年度北京流行音乐典礼'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于组织机构？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于人名？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于音乐？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于节日？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于地名？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于书籍？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于游戏？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于化学药品？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于疾病？', '空实体'],
#  ['BOT的总价要多少钱。这个句子中有哪些属于普通实体？', 'BOT'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道泰山极顶的作家是谁啊？。这个句子中有哪些属于普通实体？', '泰山极顶'],
#  ['.org的注册机构是什么。这个句子中有哪些属于组织机构？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['.org的注册机构是什么。这个句子中有哪些属于普通实体？', '.org'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于人名？', '法国斗牛犬'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于音乐？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于节日？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于地名？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于书籍？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于游戏？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于疾病？', '空实体'],
#  ['我想知道法国斗牛犬有什么特点？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问七朵水仙花的作者是谁？。这个句子中有哪些属于普通实体？', '七朵水仙花'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道皖系军阀参与了什么战争？。这个句子中有哪些属于普通实体？', '皖系军阀'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于人名？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于音乐？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于节日？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于地名？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于书籍？', '信号与系统分析'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于游戏？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于疾病？', '空实体'],
#  ['信号与系统分析什么时候印刷的？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问设计成本控制是什么意思？。这个句子中有哪些属于普通实体？', '设计成本控制'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于组织机构？', '广东省预防青少年犯罪研究会'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于人名？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于音乐？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于节日？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于地名？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于书籍？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于游戏？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于疾病？', '空实体'],
#  ['广东省预防青少年犯罪研究会由哪个单位发起？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于组织机构？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于人名？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于音乐？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于节日？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于地名？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于书籍？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于游戏？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于化学药品？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于疾病？', '空实体'],
#  ['义安公主有侄女吗，叫什么啊。这个句子中有哪些属于普通实体？', '义安公主'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于组织机构？', '你好台湾网'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问你好台湾网在哪里办公？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于人名？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于音乐？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于节日？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于地名？', '半屏岛'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于书籍？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于游戏？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于疾病？', '空实体'],
#  ['谁能告诉我半屏岛都管些什么方面的事情？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于组织机构？', '分众传媒'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于人名？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于音乐？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于节日？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于地名？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于书籍？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于游戏？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于疾病？', '空实体'],
#  ['分众传媒主营一些什么业务？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于人名？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于音乐？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于节日？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于地名？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于书籍？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于游戏？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于疾病？', '空实体'],
#  ['2005年度北京流行音乐典礼是什么类型的奖？。这个句子中有哪些属于普通实体？', '2005年度北京流行音乐典礼'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于组织机构？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于人名？', '七宝'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于音乐？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于节日？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于地名？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于书籍？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于游戏？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于化学药品？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于疾病？', '空实体'],
#  ['七宝有哪些伙伴。这个句子中有哪些属于普通实体？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于书籍？', '量子力学'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['量子力学是什么时候印刷的有人知道吗？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于人名？', '万贵妃'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于节日？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于地名？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['万贵妃有什么历史原型吗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于组织机构？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于人名？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于音乐？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于节日？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于地名？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于书籍？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于游戏？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于化学药品？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于疾病？', '空实体'],
#  ['4-4-2是什么时候流行的。这个句子中有哪些属于普通实体？', '4-4-2'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问巴西海盆东西宽多少？。这个句子中有哪些属于普通实体？', '巴西海盆'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问九女泉的水有多深？。这个句子中有哪些属于普通实体？', '九女泉'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于组织机构？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于人名？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于音乐？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于节日？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于地名？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于书籍？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于游戏？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于化学药品？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于疾病？', '空实体'],
#  ['上海公交173路的日均客运量多少。这个句子中有哪些属于普通实体？', '上海公交173路'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于组织机构？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于人名？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于音乐？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于节日？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于地名？', '不伦瑞克'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于书籍？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于游戏？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于化学药品？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于疾病？', '空实体'],
#  ['不伦瑞克的著名的大学有哪些。这个句子中有哪些属于普通实体？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于人名？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于音乐？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于节日？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于地名？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于书籍？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于游戏？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于疾病？', '空实体'],
#  ['久敬庄是什么类别的建筑？。这个句子中有哪些属于普通实体？', '久敬庄'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于游戏？', '核心元素'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道核心元素的游戏特征是什么类型的游戏吗？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于人名？', '不死天皇'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于音乐？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于节日？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于地名？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于书籍？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于游戏？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于疾病？', '空实体'],
#  ['告诉我一下不死天皇的修为呗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于地名？', '丰县'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道丰县的县委书记是谁吗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于人名？', '火凤凰'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于音乐？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于节日？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于地名？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于书籍？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于游戏？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于疾病？', '空实体'],
#  ['火凤凰是什么时候出生的？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于组织机构？', 'AIK足球俱乐部'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于人名？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于音乐？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于节日？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于地名？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于书籍？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于游戏？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于化学药品？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于疾病？', '空实体'],
#  ['AIK足球俱乐部是哪个联赛的。这个句子中有哪些属于普通实体？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于人名？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于音乐？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于节日？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于地名？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于书籍？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于游戏？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于疾病？', '空实体'],
#  ['1185年的主要事件是什么？。这个句子中有哪些属于普通实体？', '1185年'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于人名？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于音乐？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于节日？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于地名？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于书籍？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于游戏？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于疾病？', '空实体'],
#  ['请告诉我107的罗马数字。这个句子中有哪些属于普通实体？', '107'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于组织机构？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于人名？', '上官瑞谦'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于音乐？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于节日？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于地名？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于书籍？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于游戏？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于化学药品？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于疾病？', '空实体'],
#  ['告诉我上官瑞谦的女友是谁。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道阋神星的逃逸速度是多少吗？。这个句子中有哪些属于普通实体？', '阋神星'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于组织机构？', '七里河区'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于人名？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于音乐？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于节日？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于地名？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于书籍？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于游戏？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于化学药品？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于疾病？', '空实体'],
#  ['七里河区有哪些有名的大学。这个句子中有哪些属于普通实体？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于组织机构？', '乌拉圭国家男子足球队'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['乌拉圭国家男子足球队的FIFA排名是什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于组织机构？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于人名？', '严韵遥'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于音乐？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于节日？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于地名？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于书籍？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于游戏？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于化学药品？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于疾病？', '空实体'],
#  ['严韵遥的养母是谁。这个句子中有哪些属于普通实体？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于人名？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于音乐？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于节日？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于地名？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于书籍？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于游戏？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于疾病？', '空实体'],
#  ['煮羊肉具有什么营养价值？。这个句子中有哪些属于普通实体？', '煮羊肉'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于人名？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于音乐？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于节日？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于地名？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于书籍？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于游戏？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于疾病？', '空实体'],
#  ['谁是《王子外出赚钱中》的作者？。这个句子中有哪些属于普通实体？', '王子外出赚钱中'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于组织机构？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于人名？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于音乐？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于节日？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于地名？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于书籍？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于娱乐，影视节目？', '万年飘香'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于游戏？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于化学药品？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于疾病？', '空实体'],
#  ['谁知道万年飘香的执行导演啊。这个句子中有哪些属于普通实体？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于组织机构？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于人名？', '于伟'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于音乐？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于节日？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于地名？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于书籍？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于游戏？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于化学药品？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于疾病？', '空实体'],
#  ['于伟的执业证号是多少。这个句子中有哪些属于普通实体？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问蕨粉有哪些营养成分？。这个句子中有哪些属于普通实体？', '蕨粉'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于组织机构？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于书籍？', '东君草堂诗选'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['东君草堂诗选的作品题材是什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于组织机构？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于人名？', '三田佳子'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于音乐？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于节日？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于地名？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于书籍？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于游戏？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于化学药品？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于疾病？', '空实体'],
#  ['三田佳子的长子是谁。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于娱乐，影视节目？', '夺子战争1997'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道夺子战争1997的片头曲是什么啊？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道三家村的耕地面积多大吗。这个句子中有哪些属于普通实体？', '三家村'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于组织机构？', '上海交通大学苏州人工智能研究院'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['请告诉我CP的本意是什么。这个句子中有哪些属于普通实体？', 'CP'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于组织机构？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于人名？', '七濑陆'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于节日？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于地名？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['七濑陆讨厌什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于人名？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于音乐？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于节日？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于地名？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于书籍？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于游戏？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于疾病？', '空实体'],
#  ['胆绿素有哪些形态特征？。这个句子中有哪些属于普通实体？', '胆绿素'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于组织机构？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于人名？', '8比特'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于音乐？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于节日？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于地名？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于书籍？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于游戏？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于化学药品？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于疾病？', '空实体'],
#  ['要怎么获得8比特啊。这个句子中有哪些属于普通实体？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于人名？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于音乐？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于节日？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于地名？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于书籍？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于游戏？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于疾病？', '空实体'],
#  ['华中农业大学学术委员会属于哪所大学呢？。这个句子中有哪些属于普通实体？', '华中农业大学学术委员会'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于人名？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于音乐？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于节日？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于地名？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于书籍？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于游戏？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于疾病？', '空实体'],
#  ['和康居国有关的地理知识有哪些？。这个句子中有哪些属于普通实体？', '康居国'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于音乐？', 'Ich Liebe Dich'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道Ich Liebe Dich是哪个公司出版的吗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['藤山柳属属于引种吗？。这个句子中有哪些属于普通实体？', '藤山柳属'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于人名？', '东方仗助'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道东方仗助的伙伴都有谁吗。这个句子中有哪些属于普通实体？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于组织机构？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于人名？', '何清华'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于音乐？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于节日？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于地名？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于书籍？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于游戏？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于化学药品？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于疾病？', '空实体'],
#  ['搜一下何清华有几遍论文。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？。这个句子中有哪些属于普通实体？',
#   '中华人民共和国第一届全国人民代表大会第五次会议'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于组织机构？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于人名？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于音乐？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于节日？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于地名？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于书籍？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于游戏？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于化学药品？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于疾病？', '空实体'],
#  ['1952年奥斯陆冬季奥运会的比赛时间是什么时候。这个句子中有哪些属于普通实体？', '1952年奥斯陆冬季奥运会'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于人名？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于音乐？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于节日？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于地名？', '何家村'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于书籍？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于游戏？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于疾病？', '空实体'],
#  ['何家村的人均耕地面积是多少？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于人名？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于音乐？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于节日？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于地名？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于书籍？', '再次飞升'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于游戏？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于疾病？', '空实体'],
#  ['再次飞升是从哪天开始创作的？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于组织机构？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于人名？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于音乐？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于节日？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于地名？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于书籍？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于游戏？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于化学药品？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于疾病？', '空实体'],
#  ['104的罗马数字是多少。这个句子中有哪些属于普通实体？', '104'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于组织机构？', 'Afilia Saga'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于人名？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['Afilia Saga的旧名是什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于人名？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于音乐？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于节日？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于地名？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于书籍？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于游戏？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于疾病？', '空实体'],
#  ['第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？。这个句子中有哪些属于普通实体？', '第11届华盛顿影评人协会奖'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于人名？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于音乐？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于节日？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于地名？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于书籍？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于游戏？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于疾病？', '空实体'],
#  ['什么可以治疗疼痛病？。这个句子中有哪些属于普通实体？', '疼痛病'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于人名？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于音乐？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于节日？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于地名？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于书籍？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于游戏？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于疾病？', '空实体'],
#  ['康斯坦茨会议是什么时候？。这个句子中有哪些属于普通实体？', '康斯坦茨会议'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于人名？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于音乐？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于节日？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于地名？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于书籍？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于游戏？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于疾病？', '空实体'],
#  ['甩尾需要哪些步骤？。这个句子中有哪些属于普通实体？', '甩尾'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于人名？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于节日？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于地名？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问10·12宜兰地震的震源深度是多少。这个句子中有哪些属于普通实体？', '10·12宜兰地震'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于组织机构？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于人名？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于音乐？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于节日？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于地名？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于书籍？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于游戏？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于化学药品？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于疾病？', '空实体'],
#  ['有哪些球队参加了1922年巴西美洲杯。这个句子中有哪些属于普通实体？', '1922年巴西美洲杯'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于人名？', '武宫正树'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于音乐？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于节日？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于地名？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于书籍？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于游戏？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于疾病？', '空实体'],
#  ['武宫正树师从于谁？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道武定的起始地在哪吗？。这个句子中有哪些属于普通实体？', '武定'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于组织机构？', '湖北莲田食品开发有限公司'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于书籍？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问湖北莲田食品开发有限公司的主营业务有哪些？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于组织机构？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于人名？', '代庆成'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于音乐？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于节日？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于地名？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于书籍？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于游戏？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于化学药品？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于疾病？', '空实体'],
#  ['代庆成的医师级别是什么。这个句子中有哪些属于普通实体？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于人名？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于音乐？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于节日？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于地名？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于书籍？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于游戏？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于疾病？', '空实体'],
#  ['文夕大火有多少人遇难？。这个句子中有哪些属于普通实体？', '文夕大火'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于组织机构？', '中国人民武装警察部队海警总队'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于人名？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于音乐？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于节日？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于地名？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于书籍？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于游戏？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于疾病？', '空实体'],
#  ['中国人民武装警察部队海警总队属于什么机构的类型？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于人名？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于音乐？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于节日？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于地名？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于书籍？', '时间移民'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于游戏？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于疾病？', '空实体'],
#  ['请问时间移民的印张是多少？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于组织机构？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于人名？', 'N'],
#  ['N的养父是谁。这个句子中有哪些属于音乐？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于节日？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于地名？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于书籍？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于游戏？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于化学药品？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于疾病？', '空实体'],
#  ['N的养父是谁。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于书籍？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道元气娘一般都被指代成什么吗？。这个句子中有哪些属于普通实体？', '元气娘'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于组织机构？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于人名？', '中空知美咲'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于音乐？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于节日？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于地名？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于书籍？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于游戏？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于化学药品？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于疾病？', '空实体'],
#  ['中空知美咲的就读学校是什么呢。这个句子中有哪些属于普通实体？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于人名？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于音乐？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于节日？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于地名？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于书籍？', '烟火阑珊'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于游戏？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于疾病？', '空实体'],
#  ['你知道烟火阑珊的作品风格属于什么系列吗？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于人名？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于音乐？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于节日？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于地名？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于书籍？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于游戏？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于疾病？', '空实体'],
#  ['迹象展览是什么时候开幕的？。这个句子中有哪些属于普通实体？', '迹象'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于组织机构？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于人名？', 'Tony Lee'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于音乐？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于节日？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于地名？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于书籍？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于游戏？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于化学药品？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于疾病？', '空实体'],
#  ['Tony Lee有什么荣誉。这个句子中有哪些属于普通实体？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于人名？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于音乐？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于节日？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于地名？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于书籍？', '七情六欲'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于游戏？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于疾病？', '空实体'],
#  ['七情六欲是从哪天开始创作的？。这个句子中有哪些属于普通实体？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于组织机构？', 'The Bravery'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于人名？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于音乐？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于节日？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于地名？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于书籍？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于游戏？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于化学药品？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于疾病？', '空实体'],
#  ['The Bravery的建馆时间是什么时候。这个句子中有哪些属于普通实体？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于组织机构？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于人名？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于音乐？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于节日？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于地名？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于书籍？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于娱乐，影视节目？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于游戏？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于化学药品？', '空实体'],
#  ['手球的组织结构是什么啊？。这个句子中有哪些属于疾病？', '空实体']]

# %%
examples[0]
# Out:
# {'id': 0,
#  'question': '你知道长江武汉航道局管多少个地方吗？',
#  'answer': '长江武汉航道局 ||| 管辖 ||| 715.2公里'}

# %%
ner_examples=[]
for example in examples:
    triple=example['answer']
    head,rel,tail=triple.split('|||')
    head=head.strip()
    try:
        assert head in sub_map
        relations=[r for r,t in sub_map[head]]
        example.update({"relations":relations})
        ner_examples.append(example)
    except:
        print(head,example)
        #raise Exception("check")
        continue

# %%
print(ner_examples[0])
# Out:
# {'id': 0, 'question': '你知道长江武汉航道局管多少个地方吗？', 'answer': '长江武汉航道局 ||| 管辖 ||| 715.2公里', 'relations': ['职责', '中文名', '维护管理', '管辖']}

# %%
tag2attrs={"组织机构":['成立日期','创始人','总部地点','员工数','成立时间','公司类型','公司名称','创办时间','创建时间','创立','所属地区','机构特点','建立时间','机构地址'],
"人名":['国籍','毕业院校','职业','出生日期','专业方向','身高','民族','血型','体重','逝世日期','性别'],
"音乐":['填词','音乐风格','所属专辑','歌曲原唱','歌曲时长','编曲','谱曲','歌手','专辑'],
"节日":['节日类型','节日意义','节日起源','节日饮食','节日活动'],
"地名":['修建时间','所在地点','著名景点','地理位置','面积','人口数量','重建时间','营业时间','人口数','总人口'],
"书籍":['装帧','出版社','丛书','作者','出版时间','书名'],
"娱乐，影视节目":['制片人','播出时间','首播时间','片长','对白语言','上映时间','主演','票房','编剧','制片地区','首演时间','集数','播出时长'],
"游戏":['游戏类型','游戏画面','游戏引擎','游戏平台','游戏类别','所属游戏','游戏大小'],
"化学药品":['用法用量'],
"疾病":['症状','传染性','相关疾病']
}

# %%
ner_examples2=[]
for example in ner_examples:
    triple=example['answer']
    #head,rel,tail=triple.split('|||')
    relations=example['relations']
    tag='O'
    for rel in relations:
        found_each_rel=False
        for ner_tag,tag_attrs in tag2attrs.items():
            if rel in tag_attrs:
                found_each_rel=True
                break
        if found_each_rel:
            tag=ner_tag
            break
    example.update({'tag':tag})
    ner_examples2.append(example)

# %%
O_count=0
for example in ner_examples2:
    if example['tag']=='O':
        O_count+=1
        print(example)
# Out:
# {'id': 0, 'question': '你知道长江武汉航道局管多少个地方吗？', 'answer': '长江武汉航道局 ||| 管辖 ||| 715.2公里', 'relations': ['职责', '中文名', '维护管理', '管辖'], 'tag': 'O'}
# {'id': 1, 'question': '东瓯王发生的主要事件是什么？', 'answer': '东瓯王 ||| 主要事件 ||| 抗秦反秦，助汉击楚。', 'relations': ['主要事件', '中文名', '所属地', '姓氏', '东瓯王后', '代表人物'], 'tag': 'O'}
# {'id': 2, 'question': '山西省铸造新工艺工程技术研究中心是什么的管辖的啊？', 'answer': '山西省铸造新工艺工程技术研究中心 ||| 机构类型 ||| 研究开发机构', 'relations': ['机构类型', '隶属', '研究项目', '中文名'], 'tag': 'O'}
# {'id': 4, 'question': '国民军参与过什么战争？', 'answer': '国民军 ||| 参与战争 ||| 直奉战争、北伐战争、中原大战、抗日战争', 'relations': ['外文名', '别名', '所属派系', '改编时间', '首领', '中文名', '主要将领', '参与战争', '外文名', '领袖', '分化之前'], 'tag': 'O'}
# {'id': 5, 'question': '你知道诺基亚lumia1320的主屏尺寸是多少吗？', 'answer': '诺基亚lumia1320 ||| 主屏尺寸 ||| 6英寸', 'relations': ['主屏尺寸', '中文名', '型号', '品牌', '电池容量', '核心数', '代号', '像素', '外文名'], 'tag': 'O'}
# {'id': 6, 'question': '你什么时候参加的执业兽医资格考试啊？', 'answer': '执业兽医资格考试 ||| 考试时间 ||| 10月', 'relations': ['实质', '外文名', '中文名', '分类', '考试时间'], 'tag': 'O'}
# {'id': 7, 'question': '你知道2007年度北京流行音乐典礼是哪种类型的奖项吗', 'answer': '2007年度北京流行音乐典礼 ||| 奖项类型 ||| 音乐类奖项', 'relations': ['中文名', '奖项地区', '奖项类型', '别名'], 'tag': 'O'}
# {'id': 8, 'question': 'BOT的总价要多少钱', 'answer': 'BOT（dota游戏中飞鞋的简称。） ||| 总价 ||| 2450', 'relations': ['配件', '卷轴价格', '中文名', '总价'], 'tag': 'O'}
# {'id': 9, 'question': '你知道泰山极顶的作家是谁啊？', 'answer': '泰山极顶 ||| 作家 ||| 杨朔', 'relations': ['类别', '中文名', '作家', '主要描写'], 'tag': 'O'}
# {'id': 10, 'question': '.org的注册机构是什么', 'answer': '.org ||| 注册机构 ||| VeriSign等', 'relations': ['外文名', '注册机构', '性质', '属性', '适用', '全称', '域名数量', '释义'], 'tag': 'O'}
# {'id': 12, 'question': '请问七朵水仙花的作者是谁？', 'answer': '七朵水仙花 ||| 作家 ||| 金河仁', 'relations': ['中文名', '外文名', '七朵水仙花', '作家'], 'tag': 'O'}
# {'id': 13, 'question': '你知道皖系军阀参与了什么战争？', 'answer': '皖系军阀 ||| 参与战争 ||| 直皖战争、江浙战争', 'relations': ['参与战争', '中文名', '势力范围', '首领', '外文名', '主要人物', '主要将领'], 'tag': 'O'}
# {'id': 15, 'question': '请问设计成本控制是什么意思？', 'answer': '设计成本控制 ||| 阐述 ||| 生产而事先测算的产品成本', 'relations': ['中文名', '类别', '阐述', '相关'], 'tag': 'O'}
# {'id': 17, 'question': '义安公主有侄女吗，叫什么啊', 'answer': '义安公主 ||| 侄女 ||| 千金公主、清都公主等', 'relations': ['父親', '丈夫', '别称', '外甥女', '侄女', '侄女', '兄弟', '民族族群', '出生地', '姐妹', '外甥女', '本名', '所处时代', '别名'], 'tag': 'O'}
# {'id': 21, 'question': '2005年度北京流行音乐典礼是什么类型的奖？', 'answer': '2005年度北京流行音乐典礼 ||| 奖项类型 ||| 音乐类奖项', 'relations': ['中文名', '奖项地区', '奖项类型', '别名'], 'tag': 'O'}
# {'id': 25, 'question': '4-4-2是什么时候流行的', 'answer': '4-4-2 ||| 流行时间 ||| 1966年', 'relations': ['代表球队', '类别', '中文名', '流行时间', '外文名'], 'tag': 'O'}
# {'id': 26, 'question': '请问巴西海盆东西宽多少？', 'answer': '巴西海盆 ||| 东西宽 ||| 2000-2500公里', 'relations': ['外文名', '中文名', '南北长', '位于', '东西宽'], 'tag': 'O'}
# {'id': 27, 'question': '请问九女泉的水有多深？', 'answer': '九女泉 ||| 水深 ||| 2米', 'relations': ['东与', '水深', '位于', '中文名'], 'tag': 'O'}
# {'id': 28, 'question': '上海公交173路的日均客运量多少', 'answer': '上海公交173路 ||| 日均客运量 ||| 0.6 万人次', 'relations': ['车站数量', '外文名', '公交类型', '线网长度', '中文名', '使用过的车型', '始发站', '日最高客运量', '运营机构', '终点站', '运营线路', '报站语言', '车队规模', '车票价格', '可换乘', '日均客运量'], 'tag': 'O'}
# {'id': 30, 'question': '久敬庄是什么类别的建筑？', 'answer': '久敬庄 ||| 建筑类别 ||| 板楼', 'relations': ['中文名称', '建筑类别', '开放时间', '房屋类型'], 'tag': 'O'}
# {'id': 36, 'question': '1185年的主要事件是什么？', 'answer': '1185年 ||| 主要事件 ||| 大定病卒', 'relations': ['中文名', '主要事件', '又名', '别名'], 'tag': 'O'}
# {'id': 37, 'question': '请告诉我107的罗马数字', 'answer': '107 ||| 罗马数字 ||| CVII', 'relations': ['二进制', '八进制', '倒数循环节', '大写', '四进制', '中文名', '十二进制', '三进制', '十六进制', '罗马数字'], 'tag': 'O'}
# {'id': 39, 'question': '你知道阋神星的逃逸速度是多少吗？', 'answer': '阋神星 ||| 逃逸速度 ||| 1.38 km/s(±0.01)', 'relations': ['平近点角', '别名', '自转周期', '质量', '质量', '升交点经度', '表面温度', '视星等', '表面温度', '公转周期', '别称', '分类', '发现者', '发现时间', '离心率', '半长轴', '直径', '离心率', '绝对星等', '半长轴', '逃逸速度', '中文名', '发现时间', '发现者', '平均密度', '反照率', '轨道倾角', '别名', '直径', '发现者', '分类', '外文名'], 'tag': 'O'}
# {'id': 43, 'question': '煮羊肉具有什么营养价值？', 'answer': '煮羊肉 ||| 营养价值 ||| 可以增加人体热量抵御寒冷', 'relations': ['吃羊肉', '营养价值', '中文名', '食材', '属于', '功效'], 'tag': 'O'}
# {'id': 44, 'question': '谁是《王子外出赚钱中》的作者？', 'answer': '王子外出赚钱中 ||| 漫画作者 ||| サマミヤアカザ / 岩城广海', 'relations': ['漫画类型', '漫画作者', '中文名', '上架日期'], 'tag': 'O'}
# {'id': 47, 'question': '请问蕨粉有哪些营养成分？', 'answer': '蕨粉 ||| 营养成分 ||| 维生素C', 'relations': ['原料', '营养成分', '中文名', '食用功效：', '原料：', '营养成分：', '食用功效'], 'tag': 'O'}
# {'id': 51, 'question': '你知道三家村的耕地面积多大吗', 'answer': '三家村（山西平遥县香乐乡下辖村） ||| 总耕地面积 ||| 2193亩', 'relations': ['行政区类别', '总耕地面积', '人口', '中文名称'], 'tag': 'O'}
# {'id': 53, 'question': '请告诉我CP的本意是什么', 'answer': 'CP（人物配对CharacterPairing） ||| 本意 ||| 是指有恋爱关系的同人配对', 'relations': ['全称', '日文', '本意', '应用', '外文名', '中文名'], 'tag': 'O'}
# {'id': 55, 'question': '胆绿素有哪些形态特征？', 'answer': '胆绿素 ||| 形态特征 ||| 深绿色片状或柱状结晶', 'relations': ['存在位置', '中文名', '外文名', '前体物质', '分类', '形态特征'], 'tag': 'O'}
# {'id': 57, 'question': '华中农业大学学术委员会属于哪所大学呢？', 'answer': '华中农业大学学术委员会 ||| 所属院校 ||| 华中农业大学', 'relations': ['所属院校', '中文名'], 'tag': 'O'}
# {'id': 58, 'question': '和康居国有关的地理知识有哪些？', 'answer': '康居国 ||| 地理 ||| 西域三十六国之一', 'relations': ['位置', '灭亡时间', '地理', '建国时间', '中文名', '位置'], 'tag': 'O'}
# {'id': 60, 'question': '藤山柳属属于引种吗？', 'answer': '藤山柳属 ||| 引种状况 ||| 非引种', 'relations': ['拉丁学名', '科', '引种状况', '界', '分布量', '中文名'], 'tag': 'O'}
# {'id': 63, 'question': '你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？', 'answer': '中华人民共和国第一届全国人民代表大会第五次会议 ||| 会议时间 ||| 1958年2月1日', 'relations': ['主要议程', '中文名', '会议地点', '会议时间'], 'tag': 'O'}
# {'id': 64, 'question': '1952年奥斯陆冬季奥运会的比赛时间是什么时候', 'answer': '1952年奥斯陆冬季奥运会 ||| 比赛时间 ||| 1952年2月14-1952年2月25日', 'relations': ['参赛运动员', '参赛国和地区', '外文名', '比赛时间', '下一届', '中文名', '主办国和城市', '项目数', '上一届'], 'tag': 'O'}
# {'id': 67, 'question': '104的罗马数字是多少', 'answer': '104 ||| 罗马数字 ||| CIV', 'relations': ['三进制', '因数分解', '倒数循环节', '中文名', '八进制', '十二进制', '四进制', '二进制', '外文名', '罗马数字', '大写', '十六进制'], 'tag': 'O'}
# {'id': 69, 'question': '第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？', 'answer': '第11届华盛顿影评人协会奖 ||| 最佳男主角 ||| 丹尼尔·戴·刘易斯《林肯》', 'relations': ['中文名', '最佳男主角', '最佳影片', '举办时间', '最佳导演'], 'tag': 'O'}
# {'id': 70, 'question': '什么可以治疗疼痛病？', 'answer': '疼痛病 ||| 治疗 ||| 疼痛诊疗专科', 'relations': ['中文名', '发病原因', '治疗', '领域'], 'tag': 'O'}
# {'id': 71, 'question': '康斯坦茨会议是什么时候？', 'answer': '康斯坦茨会议 ||| 会议时间 ||| 1414年至1418年', 'relations': ['会议时间', '地点', '中文名', '主要议题', '时间'], 'tag': 'O'}
# {'id': 72, 'question': '甩尾需要哪些步骤？', 'answer': '甩尾（口袋妖怪技能） ||| 步骤 ||| 朝目标移动直到目标进入射程', 'relations': ['概述', '什么是甩尾', '中文名', '步骤'], 'tag': 'O'}
# {'id': 73, 'question': '请问10·12宜兰地震的震源深度是多少', 'answer': '10·12宜兰地震 ||| 震源深度 ||| 9千米', 'relations': ['震源深度', '地震时间', '中文名', '地震位置', '地震震级'], 'tag': 'O'}
# {'id': 74, 'question': '有哪些球队参加了1922年巴西美洲杯', 'answer': '1922年巴西美洲杯 ||| 参赛球队 ||| 巴拉圭、乌拉圭、巴西、阿根廷、智利', 'relations': ['亚军', '届别', '赛事类型', '冠军', '举办地', '举办时间', '参赛球队', '中文名称', '中文名'], 'tag': 'O'}
# {'id': 76, 'question': '你知道武定的起始地在哪吗？', 'answer': '武定（东魏孝静帝年号） ||| 起始 ||| 543年正月', 'relations': ['朝代', '历时', '性质', '起始', '中文名', '终止'], 'tag': 'O'}
# {'id': 79, 'question': '文夕大火有多少人遇难？', 'answer': '文夕大火 ||| 死亡人数 ||| 30000余人', 'relations': ['经济损失', '发生时间', '死亡人数', '外文名', '发生地点', '中文名', '发生地点', '中日指挥官'], 'tag': 'O'}
# {'id': 83, 'question': '你知道元气娘一般都被指代成什么吗？', 'answer': '元气娘（ACGN界用语） ||| 指代 ||| 乐观充满希望，活泼又可爱女孩子', 'relations': ['类别', '指代', '使用者', '中文名'], 'tag': 'O'}
# {'id': 86, 'question': '迹象展览是什么时候开幕的？', 'answer': '迹象（艺术展览） ||| 开幕时间 ||| 2021-03-05', 'relations': ['地点', '开幕时间', '中文名', '闭幕时间'], 'tag': 'O'}
# {'id': 90, 'question': '手球的组织结构是什么啊？', 'answer': '手球（体育类竞技运动） ||| 组织机构 ||| 国际手球联合会、 亚洲手球联合会、中国手球协会', 'relations': ['代表人物', '组织机构', '类别', '起源地', '中文名', '起源时间', '外文名'], 'tag': 'O'}
# {'id': 91, 'question': '谁知道Rong行销是哪个部门的', 'answer': 'Rong行销 ||| 隶属部门 ||| Rong融道（中国）', 'relations': ['隶属部门', '中文名', '性质', '企业类型'], 'tag': 'O'}
# {'id': 93, 'question': 'B-36的飞行速度多少', 'answer': 'B-36 ||| 飞行速度 ||| 亚音速', 'relations': ['服役时间', '退役时间', '气动布局', '中文名', '外文名', '首飞时间', '飞行速度', '研发单位'], 'tag': 'O'}
# {'id': 95, 'question': '请问SCP-CN-052的项目编号是多少？', 'answer': 'SCP-CN-052 ||| 项目编号 ||| SCP-CN-052', 'relations': ['项目编号', '项目等级', '中文名'], 'tag': 'O'}
# {'id': 99, 'question': '战略实施的实现意味着什么？', 'answer': '战略实施 ||| 实现 ||| 企业战略目标', 'relations': ['别名', '实现', '又名', '释义', '中文名'], 'tag': 'O'}
# {'id': 100, 'question': '家庭云中心是什么时候首发的？', 'answer': '家庭云中心 ||| 首发时间 ||| 2011年12月28日', 'relations': ['首发时间', '特点', '中文名', '首发公司'], 'tag': 'O'}
# {'id': 102, 'question': '你知道东皇太一达到了什么境界吗', 'answer': '东皇太一（游戏《太古妖皇诀》中的角色） ||| 境界 ||| 准圣', 'relations': ['爱好', '境界', '别名', '中文名', '势力', '身份', '法宝', '登场作品', '武器', '功法'], 'tag': 'O'}
# {'id': 103, 'question': 'TDP主要有什么应用？', 'answer': 'TDP ||| 主要应用 ||| CPU', 'relations': ['别名', '简称', '主要应用', '中文名', '外文名', '隶属'], 'tag': 'O'}
# {'id': 105, 'question': '德意志帝国议会在哪个时间段举行？', 'answer': '德意志帝国议会 ||| 会议时间 ||| 1871年4月17日', 'relations': ['时间', '类型', '中文名', '会议时间', '外文名'], 'tag': 'O'}
# {'id': 107, 'question': '辰河目连戏的项目编号是什么？', 'answer': '辰河目连戏 ||| 项目编号 ||| Ⅳ-87', 'relations': ['中文名', '申报地区', '项目类别', '批准时间', '项目编号'], 'tag': 'O'}
# {'id': 108, 'question': 'Emo大概在什么时间流行的呢', 'answer': 'Emo（一种摇滚乐风格） ||| 流行时间 ||| 1990年代', 'relations': ['中文名', '引发人物', '外文名', '属性', '流行时间', '定义'], 'tag': 'O'}
# {'id': 111, 'question': '告诉我雨露是哪儿出版的?', 'answer': '雨露（吉林省民间故事杂志社主办杂志期刊） ||| 出版单位 ||| 吉林省民间故事杂志社', 'relations': ['主办单位', '邮发代号', '语言', '定价', '中文名称', '出版单位', '国际刊号', '国外发行', '国内刊号'], 'tag': 'O'}
# {'id': 115, 'question': '环三都澳区域的陆地有多大？', 'answer': '环三都澳区域 ||| 陆地面积 ||| 1630.10平方公里', 'relations': ['三都澳', '海域面积', '陆地面积', '区域人口', '中文名'], 'tag': 'O'}
# {'id': 116, 'question': '上海马路命名备忘录是什么时候发布的？', 'answer': '上海马路命名备忘录 ||| 发布 ||| 1862年', 'relations': ['1843年后', '发布', '中文名', '1862年'], 'tag': 'O'}
# {'id': 117, 'question': '我想知道中部锦龟是怎么繁殖的？', 'answer': '中部锦龟 ||| 繁殖方式 ||| 卵生', 'relations': ['纲', '门', '拉丁学名', '亚目', '二名法', '科', '亚门', '分布区域', '繁殖方式', '界', '中文学名', '目', '种'], 'tag': 'O'}
# {'id': 125, 'question': '114怎么大写啊', 'answer': '114（自然数之一） ||| 大写 ||| 壹佰壹拾肆', 'relations': ['八进制', '大写', '二进制', '中文名', '十六进制', '倒数循环节', '十二进制', '罗马数字', '因数分解', '三进制'], 'tag': 'O'}
# {'id': 127, 'question': 'HUAWEI Mate 9的出厂系统是什么', 'answer': 'HUAWEI Mate 9 ||| 出厂系统 ||| EMUI 5.0', 'relations': ['运行内存', '外文名', '电池容量', '所属品牌', '产品类型', '中文名', '发布时间', '出厂系统', 'CPU', '屏幕尺寸'], 'tag': 'O'}
# {'id': 128, 'question': '请问澳洲鲭的俗名是什么？', 'answer': '澳洲鲭 ||| 俗名 ||| 花腹鲭', 'relations': ['资料来源', '拉丁学名', '纲', '门', '二名法', '亚门', '界', '俗名', '目', '种', '原始文献', '编号', '科', '中文学名', '亚目', '亚纲', '属', '最大长度'], 'tag': 'O'}
# {'id': 131, 'question': '中国科学技术馆的建成面积有多少？', 'answer': '中国科学技术馆（中国国家级综合性科技馆） ||| 建成 ||| 1988年9月22日', 'relations': ['适宜游玩季节', '门票价格', '所属城市', '主要功能', '隶属', '中文名', '现任馆长', '建成', '建议游玩时长', '开放时间', '所属国家', '属性', '位置'], 'tag': 'O'}
# {'id': 132, 'question': '特殊教育学专业主要培养目标是什么？', 'answer': '特殊教育学专业 ||| 培养目标 ||| 普通教育和特殊教育的知识和能力', 'relations': ['培养要求', '主干学科', '概述', '培养目标', '修业时间', '中文名'], 'tag': 'O'}
# {'id': 133, 'question': '双龙村有多少农户？', 'answer': '双龙村（云南省临沧凤庆县大寺乡双龙村） ||| 农户 ||| 769户', 'relations': ['农户', '中文名', '耕地面积', '乡村人口'], 'tag': 'O'}
# {'id': 135, 'question': '麻烦你告诉我一下铁道大厦具体地址？', 'answer': '铁道大厦 ||| 酒店地址 ||| 杭州上城区城站广场8号', 'relations': ['酒店地址', '中文名', '定性', '酒店星级'], 'tag': 'O'}
# {'id': 136, 'question': '秦皇岛新澳海底世界在哪里有人知道吗？', 'answer': '秦皇岛新澳海底世界 ||| 展馆位置 ||| 秦皇岛市海港区河滨路81号', 'relations': ['展馆主题', '门票价格', '建议游玩时长', '开放时间', '建筑面积', '展馆位置', '开放时间', '竣工时间', '展馆名称', '建筑面积', '适宜游玩季节', '景点级别', '开工时间', '门票价格'], 'tag': 'O'}
# {'id': 138, 'question': 'D4射线的制造者是哪个呢', 'answer': 'D4射线 ||| 制造者 ||| GAFJ', 'relations': ['外文名', '别名', '使用者', '中文名', '制造者'], 'tag': 'O'}
# {'id': 142, 'question': '你知道两当县人民政府的县长是哪个', 'answer': '两当县人民政府 ||| 县长 ||| 郭省军', 'relations': ['县长', '地址', '中文名'], 'tag': 'O'}
# {'id': 144, 'question': '你知道甑字的偏旁是什么吗？', 'answer': '甑 ||| 简体部首 ||| 瓦', 'relations': ['读音', '作用', '注音', '总笔画', '地区', '结构', '简体部首', '造字法', '中文名', '部首笔画'], 'tag': 'O'}
# {'id': 145, 'question': '你知道中国2010年上海世博会云南馆的名字吗？', 'answer': '中国2010年上海世博会云南馆 ||| 展馆名称 ||| 中国2010年上海世博会云南馆', 'relations': ['造型亮点', '展馆主题', '展馆名称', '展馆位置', '活动周'], 'tag': 'O'}
# {'id': 146, 'question': '你知道中马铁路的沿途有哪些城市吗', 'answer': '中马铁路（马来西亚铁路线路） ||| 沿途城市 ||| 哥打峇鲁、瓜拉登嘉楼、关丹、吉隆坡市', 'relations': ['沿途城市', '途径州属', '中文名', '外文名', '线路长度', '主要承建单位', '设计速度'], 'tag': 'O'}
# {'id': 147, 'question': '请告诉我兰陵颂由谁创作？', 'answer': '兰陵颂 ||| 作家 ||| 练喻轩', 'relations': ['中文名', '练喻轩', '作品原文', '作家'], 'tag': 'O'}
# {'id': 149, 'question': '中草药栽培技术的修学年限是多长时间', 'answer': '中草药栽培技术（中国普通高等学校专科专业） ||| 修学年限 ||| 三年', 'relations': ['一级学科', '专业代码', '修学年限', '中文名'], 'tag': 'O'}
# {'id': 150, 'question': '在粤语中，乌鼠要怎么拼啊', 'answer': '乌鼠 ||| 粤语拼音 ||| wu1 syu2', 'relations': ['粤语拼音', '语种', '中文名'], 'tag': 'O'}
# {'id': 153, 'question': '万科美景魅力之城的交房时间是什么时候', 'answer': '万科美景魅力之城 ||| 交房时间 ||| 2016-12', 'relations': ['容积率', '开发商', '预售许可证', '占地面积', '城区', '板块', '总户数', '产权类型', '户型面积', '楼盘名', '楼盘地址', '物业公司', '均价', '物业费', '绿化率', '销售状态', '产权年限', '建筑形式', '物业办公地点', '交房时间', '开盘时间', '建筑面积', '物业类别', '装修情况', '城市'], 'tag': 'O'}
# {'id': 154, 'question': '中国历史地理的开课时间是什么时候', 'answer': '中国历史地理（北京大学提供的慕课课程） ||| 开课时间 ||| 2017年春夏（首次）', 'relations': ['开课时间', '提供院校', '授课平台', '授课教师', '中文名', '类别'], 'tag': 'O'}
# {'id': 155, 'question': '印度航空182号航班事故的死亡人数有多少？', 'answer': '印度航空182号航班事故 ||| 死亡人数 ||| 329人死亡', 'relations': ['发生时间', '出发地', '发生地', '中文名', '时间', '目的地', '死亡人数'], 'tag': 'O'}
# {'id': 156, 'question': '我想知道宣肺化痰可以治疗什么？', 'answer': '宣肺化痰 ||| 治疗 ||| 外感风寒，痰涎壅肺', 'relations': ['中文名', '类型', '治疗', '材料'], 'tag': 'O'}
# {'id': 158, 'question': '你了解古格藏香坊属于什么公司吗？', 'answer': '古格藏香坊 ||| 隶属公司 ||| 华藏香堂', 'relations': ['类别', '隶属公司', '吉祥理念', '中文名'], 'tag': 'O'}
# {'id': 162, 'question': '告诉我117的四进制啊', 'answer': '117（自然数之一） ||| 四进制 ||| 1311', 'relations': ['四进制', '中文名', '倒数循环节', '三进制', '十六进制', '二进制', '大写', '因数分解', '十二进制', '罗马数字', '八进制'], 'tag': 'O'}
# {'id': 163, 'question': '你知道245国道途经哪些省份吗', 'answer': '245国道 ||| 途经省份 ||| 四川、云南', 'relations': ['起点', '国道编号', '中文名', '走向', '终点', '途经省份'], 'tag': 'O'}
# {'id': 165, 'question': '干果有哪些营养成分？', 'answer': '干果 ||| 营养成分 ||| 蛋白质、维生素、脂质等', 'relations': ['拼音', '中文名', '外文名', '营养成分', '种类', '出处', '古名', '分类'], 'tag': 'O'}
# {'id': 166, 'question': '你了解金属恶魔牛的罕贵度吗？', 'answer': '金属恶魔牛 ||| 罕贵度 ||| 银碎SER', 'relations': ['星级', '外文名', '使用者', '罕贵度', '卡种', '卡片密码', '中文名'], 'tag': 'O'}
# {'id': 169, 'question': '你知道梁带村遗址从西边到东边一共多少公里长？', 'answer': '梁带村遗址 ||| 东西长 ||| 600米', 'relations': ['南北宽', '位置', '墓地面积', '中文名', '东西长', '类别', '时期', '所属国家'], 'tag': 'O'}
# {'id': 170, 'question': '你认识dig dig dig的主讲老师吗', 'answer': 'dig dig dig ||| 主讲教师 ||| 韩娟', 'relations': ['中文名', '主讲教师', '类别', '提供学校'], 'tag': 'O'}
# {'id': 171, 'question': '七里香溪的装修情况怎么样', 'answer': '七里香溪（桐城市楼盘七里香溪） ||| 装修情况 ||| 毛坯', 'relations': ['建筑形式', '别名', '容积率', '物业公司', '产权类型', '环线位置', '销售状态', '户型面积', '楼盘地址', '物业费', '开盘时间', '建筑结构', '均价', '预售许可证', '产权年限', '占地面积', '开发商', '装修情况', '城区', '城市', '中文名', '绿化率', '建筑面积', '物业类别', '板块'], 'tag': 'O'}
# {'id': 172, 'question': '你知道中国特色社会主义理论与实践研究什么时间开课的嘛', 'answer': '中国特色社会主义理论与实践研究（暨南大学提供的慕课课程） ||| 开课时间 ||| 2018年04月02日（首次）', 'relations': ['提供院校', '授课教师', '中文名', '授课平台', '开课时间', '类别'], 'tag': 'O'}
# {'id': 174, 'question': '请问江苏省普通高中星级评估属于什么机构？', 'answer': '江苏省普通高中星级评估 ||| 组织机构 ||| 江苏省教育厅', 'relations': ['评估机构', '实施时间', '时间', '目的', '人员', '组织机构', '评估机构', '中文名', '评估等级'], 'tag': 'O'}
# {'id': 176, 'question': '哪些国家在使用001啊', 'answer': '001（美国和加拿大的国际区号） ||| 使用国家 ||| 美国、加拿大', 'relations': ['使用国家', '中文名', '创立者', '分类'], 'tag': 'O'}
# {'id': 177, 'question': '请问国际人类基因组计划1%的项目编号是什么啊？', 'answer': '国际人类基因组计划1%（3号染色体短臂末端）基因组测序 ||| 项目编号 ||| Z-106-2-02', 'relations': ['项目编号', '完成人', '中文名', '获奖情况'], 'tag': 'O'}
# {'id': 178, 'question': '你知道Brain驱动器的制造者吗', 'answer': 'Brain驱动器 ||| 制造者 ||| 克里斯塔尔·帕普勒', 'relations': ['外文名', '使用者', '登场作品', '中文名', '音效CV', '制造者'], 'tag': 'O'}
# {'id': 182, 'question': '什么时候召开了黑龙江嫩江联合省？', 'answer': '黑龙江嫩江联合省 ||| 会议时间 ||| 1947年2月2日', 'relations': ['时间', '中文名', '简称', '会议时间', '地点'], 'tag': 'O'}
# {'id': 183, 'question': 'W32.Sasser.Worm是被谁发现的？', 'answer': 'W32.Sasser.Worm ||| 发现 ||| 2004 年 4 月 30 日', 'relations': ['外文名', '类型', '发现', '更新'], 'tag': 'O'}
# {'id': 185, 'question': '㐆的字形结构是什么', 'answer': '㐆 ||| 字形结构 ||| 独体', 'relations': ['郑码', '统一码', '部首', '字形结构', '拼音', '仓颉', '中文名', '五笔', '注音'], 'tag': 'O'}
# {'id': 195, 'question': '你什么时候参加的城市规划师考试的啊？', 'answer': '城市规划师 ||| 考试时间 ||| 10 月中旬', 'relations': ['考务主管', '开始时间', '颁布者', '颁布日期', '颁发证书', '考试时间', '颁布者', '中文名', '要求', '发布机构'], 'tag': 'O'}
# {'id': 196, 'question': '你知道G6025次途经哪里嘛', 'answer': 'G6025次 ||| 途经省份 ||| 湖南、广东', 'relations': ['中文名', '途经线路', '总里程', '所属铁路局', '全程时间', '途经省份', '开车时间', '运行区段', '终到时间', '车底', '列车等级', '类型'], 'tag': 'O'}
# {'id': 197, 'question': '尚蛙会员联盟应实现？', 'answer': '尚蛙会员联盟 ||| 实现 ||| 分析客户信息得出相应的分析数据', 'relations': ['实现', '参加', '简介', '中文名'], 'tag': 'O'}
# {'id': 200, 'question': '飓风威尔玛死了多少人？', 'answer': '飓风威尔玛 ||| 死亡人数 ||| 23人直接 40人间接', 'relations': ['中文名', '财产损失', '外文名', '消散日期', '形成日期', '风暴强度', '中心风速', '最低气压', '中心风速', '死亡人数'], 'tag': 'O'}
# {'id': 201, 'question': '黄滔他的属地在哪？', 'answer': '黄滔（四川省一级裁判员） ||| 属地 ||| 成都', 'relations': ['属地', '中文名'], 'tag': 'O'}
# {'id': 202, 'question': '什么是科托卡国际机场的三字代码？', 'answer': '科托卡国际机场 ||| 三字代码 ||| ACC', 'relations': ['三字代码', '四字代码', '中文名', '外文名'], 'tag': 'O'}
# {'id': 203, 'question': '你知道上海公交14路途经哪些地区', 'answer': '上海公交14路 ||| 途经地区 ||| 上海市黄浦区、虹口区、杨浦区', 'relations': ['运营状态', '票制票价', '运营机构', '途经地区', '车站数量', '终点站', '开通时间', '下行首末班', '外文名', '中文名', '起点站', '上行首末班', '线路长度', '线路类型'], 'tag': 'O'}
# {'id': 204, 'question': '当代联坛青年五人作品集是哪个单位出版的？', 'answer': '当代联坛青年五人作品集 ||| 出版单位 ||| 中国诗词楹联出版社', 'relations': ['出版单位', '中文名'], 'tag': 'O'}
# {'id': 205, 'question': '1143.5型航空母舰的下水时间是什么时候呢', 'answer': '1143.5型航空母舰 ||| 下水时间 ||| 1985年12月4日', 'relations': ['服役时间', '建造单位', '下水时间', '研制时间', '设计单位', '国家', '建造数量', '服役情况', '英文名称', '中文名称', '前型/级', '舰型', '中文名', '次型/级', '外文名'], 'tag': 'O'}
# {'id': 206, 'question': '请问黄初平的编号是多少？', 'answer': '黄初平（黄大仙）传说 ||| 项目编号 ||| Ⅰ-39', 'relations': ['批准时间', '项目编号', '中文名', '遗产类别', '申报地区', '非遗级别'], 'tag': 'O'}
# {'id': 208, 'question': '菌丝的亮度是多少？', 'answer': '菌丝（Minecraft中的一种方块） ||| 亮度 ||| 无', 'relations': ['自然生成', '开采工具', '可再生', '掉落物', '数据值', '透明', '外文名', '爆炸抗性', '可燃烧', '可堆叠', '中文名', '亮度'], 'tag': 'O'}
# {'id': 209, 'question': '白色链霉菌有什么形态特征？', 'answer': '白色链霉菌 ||| 形态特征 ||| 孢子丝紧密或松敞螺旋形', 'relations': ['界', '形态特征', '中文学名', '门', '拉丁学名'], 'tag': 'O'}
# {'id': 210, 'question': '你知道1123型航空母舰什么时候下水的', 'answer': '1123型航空母舰 ||| 下水时间 ||| 1965年1月14日', 'relations': ['次型/级', '中文名称', '前型/级', '下水时间', '国家', '建造单位', '服役时间', '英文名称', '设计单位', '建造数量', '舰型', '研制时间', '服役情况', '外文名', '中文名'], 'tag': 'O'}
# {'id': 213, 'question': '你知道1·11香格里拉火灾事故造成了什么经济损失吗', 'answer': '1·11香格里拉火灾事故 ||| 经济损失 ||| 1亿多元人民币', 'relations': ['事故时间', '中文名', '经济损失', '事故地点', '事故原因'], 'tag': 'O'}
# {'id': 214, 'question': '你知道iPhone 4的摄像头是多少像素吗？', 'answer': 'iPhone 4 ||| 摄像头 ||| 后置摄像头500万像素，前置摄像头30万像素', 'relations': ['摄像头', '终止技术支持', '操作系统', '开发商', '内存', '出厂系统', '设备型号', '产品类型', '中文名', '外文名', '摄像头', '屏幕分辨率', '上市时间', '屏幕大小', '发行时间', '版本', '处理器', '所属品牌', '运行内存', '中文名'], 'tag': 'O'}
# {'id': 216, 'question': '在梁山，孔亮排多少位', 'answer': '孔亮（小说《水浒传》人物） ||| 梁山位次 ||| 63', 'relations': ['对应星号', '所处时代', '绰号', '梁山位次', '梁山职司', '梁山位次', '籍贯', '登场作品', '中文名', '登场回目', '所用兵器', '上山前身份', '出身'], 'tag': 'O'}
# {'id': 217, 'question': '上海市住房保障和房屋管理局有哪些副局长', 'answer': '上海市住房保障和房屋管理局 ||| 副局长 ||| 庞元', 'relations': ['地点', '隶属', '中文名', '副局长', '纪检组长', '隶属单位', '职责'], 'tag': 'O'}
# {'id': 218, 'question': '链孢囊菌属有哪些形态特征？', 'answer': '链孢囊菌属 ||| 形态特征 ||| 孢囊球形至卵状，直径7-48微米', 'relations': ['形态特征', '参考文献', '中文名', '外文名'], 'tag': 'O'}
# {'id': 219, 'question': '请问巴赫大提琴组曲有哪些资源？', 'answer': '巴赫大提琴组曲 ||| 资源类型 ||| APE', 'relations': ['外文名', '中文名', '发行时间', '资源类型'], 'tag': 'O'}
# {'id': 220, 'question': 'soho中山广场有什么交通线路？', 'answer': 'soho中山广场 ||| 轨道交通 ||| 3号线,4号线,10号线,', 'relations': ['中文名', '轨道交通', '竣工年份', '城市', '地区', '物业费'], 'tag': 'O'}
# {'id': 221, 'question': '什么事汽车排气系统？', 'answer': '汽车排气系统 ||| 是指 ||| 收集并且排放废气的系统', 'relations': ['属性', '性质', '中文名', '是指'], 'tag': 'O'}
# {'id': 225, 'question': '你知道公共管理与公共服务用地是什么吗？', 'answer': '公共管理与公共服务用地 ||| 主旨 ||| 土地按标准正确分类', 'relations': ['日期实施', '类型', '中文名', '主旨', '使用', '分类', '应用场景'], 'tag': 'O'}
# {'id': 227, 'question': '东北野战军第二纵队的司令员叫什么', 'answer': '东北野战军第二纵队 ||| 司令员 ||| 刘震', 'relations': ['时期', '优点', '中文名', '司令员'], 'tag': 'O'}
# {'id': 228, 'question': '翟家古城遗址的东西长是多少？', 'answer': '翟家古城遗址 ||| 东西长 ||| 约1000米', 'relations': ['东西长', '中文名', '位于', '南北宽'], 'tag': 'O'}
# {'id': 229, 'question': '请问R136a2的逃逸速度是多少？', 'answer': 'R136a2 ||| 逃逸速度 ||| 10 km/s', 'relations': ['别名', '光度', '质量', '可见光度', '观测资料', '演化阶段', '光谱', '视星等', '公转周期', '绝对星等', '半长轴', '中文名', '表面温度', '外文名', '赤经', '色指数B-V', '发现时间', '反照率', '星座', '距地距离', '赤纬', '逃逸速度', '金属丰度', '发现者', '直径', '自转周期', '旋转速度', '分类'], 'tag': 'O'}
# {'id': 230, 'question': '缪的简体部首是什么？', 'answer': '缪（汉语汉字） ||| 简体部首 ||| 纟', 'relations': ['繁体字部首', '中文名', '笔顺编号', '四角号码', '拼音', '笔顺读写', '繁体字', '词性', '五笔86&98', '仓颉', '简体部外笔画', '简体部首', '外文名', 'UniCode', '统一码', '总笔画', '简体总笔画'], 'tag': 'O'}
# {'id': 231, 'question': '北京市慈善义工协会是哪个部门批准的？', 'answer': '北京市慈善义工协会 ||| 批准部门 ||| 北京市民政局', 'relations': ['外文名', '注册资金', '协会性质', '主管单位', '中文名', '批准部门'], 'tag': 'O'}
# {'id': 232, 'question': '什么是谁来一起午餐的主旨？', 'answer': '谁来一起午餐 ||| 主旨 ||| 发掘职场潜力', 'relations': ['主持', '类型', '主旨', '主旨', '口号', '主持人', '国家/地区', '中文名', '首播', '口号', '首播'], 'tag': 'O'}
# {'id': 233, 'question': '请说出四正推手的要点是什么？', 'answer': '四正推手 ||| 要点 ||| 在双方推手时，手要严', 'relations': ['分类', '预备姿势', '要点', '中文名'], 'tag': 'O'}
# {'id': 234, 'question': '苾的部首是什么？', 'answer': '苾 ||| 简体部首 ||| 艹', 'relations': ['拼音', '简体部首', '字意', '总笔画', '中文名'], 'tag': 'O'}
# {'id': 237, 'question': 'E-Type是哪个时期的', 'answer': 'E-Type（捷豹(Jaguar)旗下跑车型号） ||| 所处时期 ||| 1961年至1974年', 'relations': ['外文名', '所属', '类别', '中文名', '所处时期', '所属公司'], 'tag': 'O'}
# {'id': 238, 'question': '我想知道尼日利亚COC认证是谁发布的啊？', 'answer': '尼日利亚COC认证 ||| 发布 ||| 尼日利亚国家标准局', 'relations': ['适用', '实行', '中文名', '发布'], 'tag': 'O'}
# {'id': 239, 'question': '谁知道三十三中站有几个出入口', 'answer': '三十三中站 ||| 出入口数 ||| 3个', 'relations': ['启用日期', '车站位置', '途经线路', '站台数目', '外文名', '出入口数', '壮文名', '中文名'], 'tag': 'O'}
# {'id': 240, 'question': '过氧化物效应是什么时候发现的？', 'answer': '过氧化物效应 ||| 发现 ||| 1933年，卡拉施等人', 'relations': ['产物', '外文名', '特点', '中文名', '别名', '发现'], 'tag': 'O'}
# {'id': 244, 'question': '101的十六进制是多少', 'answer': '101（自然数之一） ||| 十六进制 ||| 65', 'relations': ['中文名', '四进制', '十二进制', '倒数循环节', '十六进制', '八进制', '三进制', '二进制', '大写', '罗马数字'], 'tag': 'O'}
# {'id': 245, 'question': '中国儿童戏剧节什么时候开幕？', 'answer': '中国儿童戏剧节 ||| 开幕时间 ||| 2011年7月16日至8月28日', 'relations': ['中文名', '演出场数', '举办天数', '开幕时间'], 'tag': 'O'}
# {'id': 246, 'question': '你知道2030年世界杯是多少个参加比赛的队数啊？', 'answer': '2030年世界杯 ||| 参赛队数 ||| 48支球队', 'relations': ['上一届', '举办时间', '届数', '参赛队数', '下一届', '举办国家', '外文名', '举办场馆', '中文名', '比赛场数'], 'tag': 'O'}
# {'id': 247, 'question': 'Abhishek Sharma和哪个导演合作', 'answer': 'Abhishek Sharma ||| 合作导演 ||| Ashtar Sayed', 'relations': ['外文名', '合作导演', '代表作品', '职务'], 'tag': 'O'}
# {'id': 248, 'question': '请问信用的意思是什么？', 'answer': '信用 ||| 词意 ||| 能够履行诺言而取得的信任', 'relations': ['定义', '注音', '词意', '注音', '外文名', '中文名'], 'tag': 'O'}
# {'id': 249, 'question': '世自在王佛在什么文献中有记载啊', 'answer': '世自在王佛 ||| 记载文献 ||| 《无量寿经》', 'relations': ['外文名', '所属', '中文名', '记载文献', '所属分类', '别名', '别称', '身份'], 'tag': 'O'}
# {'id': 250, 'question': '你知道泊林花园是什么建筑类别吗？', 'answer': '泊林花园 ||| 建筑类别 ||| 塔楼 高层', 'relations': ['建筑类别', '物业类别', '项目特色', '中文名'], 'tag': 'O'}
# {'id': 252, 'question': '你知道波动爆发的冷却时间吗？', 'answer': '波动爆发 ||| 冷却时间 ||| 15秒', 'relations': ['中文名', '学习等级', '冷却时间', '施放时间', '所属职业', '消耗MP'], 'tag': 'O'}
# {'id': 255, 'question': '中国元素的开课时间是什么时候', 'answer': '中国元素（江苏食品药品专业技术学院提供的慕课） ||| 开课时间 ||| 2017年09月01日（首次）', 'relations': ['提供院校', '授课平台', '中文名', '开课时间', '类别', '授课教师'], 'tag': 'O'}
# {'id': 256, 'question': '金块是多少的亮度啊？', 'answer': '金块 ||| 亮度 ||| 否', 'relations': ['外文名', '中文名', '亮度', '叠加', '透明', '外文名', '粒子效果', '类型', '获得方式', '掉落', '挖掘工具', '重力影响'], 'tag': 'O'}
# {'id': 259, 'question': '你能解释一下批处理的含义吗？', 'answer': '批处理 ||| 词意 ||| 对某对象进行批量的处理', 'relations': ['外文名', '中文名', '外文名', '扩展名', '别名', '词意'], 'tag': 'O'}
# {'id': 262, 'question': '你知道东岩寺用过哪些名字吗', 'answer': '东岩寺（浙江省浦江县寺庙） ||| 旧名 ||| 东岩庵', 'relations': ['旧名', '位于', '又名', '中文名', '别名'], 'tag': 'O'}
# {'id': 265, 'question': '10·12纽约布鲁克林枪击案的伤亡怎么样', 'answer': '10·12纽约布鲁克林枪击案 ||| 伤亡 ||| 4人死亡、3人受伤', 'relations': ['伤亡', '发生地点', '中文名', '发生时间'], 'tag': 'O'}
# {'id': 267, 'question': '全国离子液体与绿色过程学术会议是哪个单位发起的？', 'answer': '全国离子液体与绿色过程学术会议 ||| 发起单位 ||| 中科院过程所与大连化物理所', 'relations': ['首届举办时间', '发起单位', '外文名', '中文名'], 'tag': 'O'}
# {'id': 268, 'question': '存储芯片的主要应用是什么？', 'answer': '存储芯片 ||| 主要应用 ||| 企业级存储系统的应用', 'relations': ['中文名', '操作方式', '主要应用', '发展前景', '外文名'], 'tag': 'O'}
# {'id': 269, 'question': '前口蝠鲼有什么形态特征？', 'answer': '前口蝠鲼 ||| 形态特征 ||| 体盘宽大，呈菱形', 'relations': ['形态特征', '分布区域', '中文学名', '界'], 'tag': 'O'}
# {'id': 270, 'question': '蓝色海岸的均价是多少？', 'answer': '蓝色海岸 ||| 均价 ||| 14486元/㎡', 'relations': ['楼盘名', '均价', '楼盘地址', '城区'], 'tag': 'O'}
# {'id': 271, 'question': '请问AL-41F发动机的总师是谁呀', 'answer': 'AL-41F发动机 ||| 总设计师 ||| 车金博士', 'relations': ['最大状态推力', '研发公司', '研制时间', '中文名', '总设计师'], 'tag': 'O'}
# {'id': 272, 'question': '你知道南亚运动会是由谁举办的吗？', 'answer': '南亚运动会 ||| 举办方 ||| 南亚地区合作组织', 'relations': ['中文名', '性质', '外文名', '举办方', '宗旨', '开始时间'], 'tag': 'O'}
# {'id': 273, 'question': '请问一级法人有什么权利', 'answer': '一级法人 ||| 权利 ||| 依法独立享有民事权利', 'relations': ['特指', '权利', '中文名', '组织解释'], 'tag': 'O'}
# {'id': 274, 'question': '三江西路的建设单位是什么', 'answer': '三江西路 ||| 建设单位 ||| 双流县城乡建设局', 'relations': ['建设地点', '红线宽', '总长', '外文名', '总投资', '项目名称', '中文名', '建设单位'], 'tag': 'O'}
# {'id': 276, 'question': '焦月是什么原因起这个名字的啊？', 'answer': '焦月 ||| 得名原因 ||| 六月赤日炎炎，万物渐焦', 'relations': ['含义', '中文名', '别名', '别称', '拼音', '特征', '得名原因'], 'tag': 'O'}
# {'id': 277, 'question': '你知道有关视网膜显示屏的发布信息吗？', 'answer': '视网膜显示屏 ||| 发布 ||| 苹果公司在2010年发布', 'relations': ['原理', '外文名', '过程', '发布', '中文名', '特点', '显示器'], 'tag': 'O'}
# {'id': 278, 'question': 'Full House Kiss是什么时候发售的？', 'answer': 'Full House Kiss ||| 发售日期 ||| 2006年2月23日', 'relations': ['外文名', '发售日期', '日文', '中文名'], 'tag': 'O'}
# {'id': 279, 'question': '你知道第22届东京电影节是什么获得的最佳男主角？', 'answer': '第22届东京电影节 ||| 最佳男主角 ||| 克里斯托·克里斯托夫', 'relations': ['最佳女主角', '地点', '中文名', '最佳男主角', '举办时间'], 'tag': 'O'}
# {'id': 280, 'question': '255省道限速多少', 'answer': '255省道（广东省境内省道） ||| 限速 ||| 60-80km/h', 'relations': ['外文名', '编号', '中文名', '限速'], 'tag': 'O'}
# {'id': 281, 'question': '你知道东汉镂雕东王公西王母纹玉座屏的文物级别吗', 'answer': '东汉镂雕东王公西王母纹玉座屏 ||| 文物级别 ||| 一级文物', 'relations': ['所属年代', '出土地点', '文物类别', '馆藏地点', '中文名', '文物级别'], 'tag': 'O'}
# {'id': 284, 'question': '昆仑山隧道起止点是哪里？', 'answer': '昆仑山隧道 ||| 线路 ||| 青藏铁路', 'relations': ['全长', '位置', '中文名', '海拔', '线路', '海拔'], 'tag': 'O'}
# {'id': 285, 'question': '你认识body language的主讲老师吗', 'answer': 'body language（body language） ||| 主讲教师 ||| 周晓婷', 'relations': ['主讲教师', '提供学校', '类别', '外文名'], 'tag': 'O'}
# {'id': 287, 'question': '你知道C-123运输机能飞多快呀', 'answer': 'C-123运输机 ||| 飞行速度 ||| 亚音速', 'relations': ['气动布局', '外文名', '国家', '首飞时间', '飞行速度', '研发单位', '中文名', '绰号', '服役时间'], 'tag': 'O'}
# {'id': 288, 'question': '谁是开封府志的责任者？', 'answer': '开封府志 ||| 责任者 ||| 管竭忠', 'relations': ['所属年代', '中文名', '中文名称', '责任者', '总册数'], 'tag': 'O'}
# {'id': 292, 'question': '有人知道田鱼的主要营养成分是啥吗？', 'answer': '田鱼 ||| 营养成分 ||| 蛋白质', 'relations': ['中文名', '产地', '俗称', '营养成分', '正式名', '外文名'], 'tag': 'O'}
# {'id': 293, 'question': '艾德盖恩：平原镇屠夫资源是什么类型？', 'answer': '艾德盖恩：平原镇屠夫 ||| 资源类型 ||| DVDRip', 'relations': ['中文名', '外文名', '资源类型', '电影导演'], 'tag': 'O'}
# {'id': 294, 'question': '图像预处理的实现意味着什么？', 'answer': '图像预处理 ||| 实现 ||| 灰度级变换(点运算)的实现', 'relations': ['实现', '变换实例', '中文名', '含义'], 'tag': 'O'}
# {'id': 295, 'question': '请问1998年法国世界杯有多少队参赛？', 'answer': '1998年法国世界杯 ||| 参赛队数 ||| 32支球队', 'relations': ['吉祥物', '决赛场地', '中文名', '口号', '外文名', '比赛场数', '举办时间', '冠军', '主办国家', '上一届', '下一届', '参赛队数'], 'tag': 'O'}
# {'id': 297, 'question': '升职记是谁开发的？', 'answer': '升职记 ||| 开发 ||| 腾讯', 'relations': ['中文名', '类型', '类型', '开发'], 'tag': 'O'}
# {'id': 298, 'question': '请问天津快板的项目编号是什么啊？', 'answer': '天津快板 ||| 项目编号 ||| Ⅴ-2', 'relations': ['表演形式', '经典剧目', '始兴年代', '流行地区', '主要特征', '形成时间', '遗产类别', '类型', '伴奏乐器', '中文名', '项目编号'], 'tag': 'O'}
# {'id': 299, 'question': '你知道052型驱逐舰什么时候下水的', 'answer': '052型驱逐舰 ||| 下水时间 ||| 1993年10月', 'relations': ['数量', '研制时间', '中文名称', '服役时间', '国家', '次型/级', '前型/级', '服役时间', '下水时间', '英文名称'], 'tag': 'O'}
# {'id': 300, 'question': '全字母句何意？', 'answer': '全字母句 ||| 意为 ||| “每一个字母”', 'relations': ['中文名', '希腊语', '意为', '外文名'], 'tag': 'O'}
# {'id': 301, 'question': 'Jimmy参加过什么节目', 'answer': 'Jimmy（号外乐团成员） ||| 参加节目 ||| 《乐队的夏天》', 'relations': ['所在乐队', '乐队身份', '外文名', '参加节目'], 'tag': 'O'}
# {'id': 302, 'question': 'A-129武装直升机是什么类型的飞机', 'answer': 'A-129武装直升机 ||| 飞机类型 ||| 武装直升机', 'relations': ['研制时间', '飞机类型', '服役时间', '前型/级', '英文名称', '中文名', '研制公司', '中文名称', '制造数量', '外文名', '国家', '次型/级'], 'tag': 'O'}
# {'id': 304, 'question': '做二次加压供水设备最重要的是什么？', 'answer': '二次加压供水设备 ||| 要点 ||| 二次加压供水', 'relations': ['创新点', '中文名', '劣势', '文件', '要点', '特点'], 'tag': 'O'}
# {'id': 305, 'question': '我很好奇开州站有多少条线路？', 'answer': '开州站 ||| 线路 ||| 西渝高铁', 'relations': ['中文名', '建筑规模', '外文名', '线路'], 'tag': 'O'}
# {'id': 307, 'question': '我很好奇毕业季是指哪些人？', 'answer': '毕业季（新兴词语） ||| 人群 ||| 大学生、中学生 小学生', 'relations': ['人群', '时间', '发生时间', '内容', '中文名', '外文名'], 'tag': 'O'}
# {'id': 308, 'question': '1212是什么时候停播的', 'answer': '1212 ||| 停播时间 ||| 2004年12月28日', 'relations': ['停播时间', '每集长度', '中文名', '重播', '首播', '播出状态'], 'tag': 'O'}
# {'id': 310, 'question': '你知道格洛里厄斯群岛的陆地面积吗？', 'answer': '格洛里厄斯群岛 ||| 陆地面积 ||| 5平方公里', 'relations': ['中文名', '陆地面积', '外文名', '地点'], 'tag': 'O'}
# {'id': 315, 'question': '你知道HZCD唱片的ISRC吗', 'answer': 'HZCD唱片 ||| ISRC ||| CNA070800250', 'relations': ['条形码', 'ISRC', '中文名', '外文名'], 'tag': 'O'}
# {'id': 318, 'question': '你知道最后的天使的专辑名称叫什么吗？', 'answer': '最后的天使 ||| 专辑名称 ||| 最后的天使', 'relations': ['外文名', '中文名', '发行时间', '专辑名称'], 'tag': 'O'}
# {'id': 319, 'question': '你知道空降奇兵的资源类型是什么吗？', 'answer': '空降奇兵 ||| 资源类型 ||| Bin', 'relations': ['英文名称', '中文名', '外文名', '发行时间', '资源类型'], 'tag': 'O'}
# {'id': 320, 'question': '你知道复述课文有什么体现吗？', 'answer': '复述课文 ||| 体现 ||| 事件的时间', 'relations': ['就是', '开展', '体现', '中文名'], 'tag': 'O'}
# {'id': 321, 'question': '什么事唐狮子牡丹？', 'answer': '唐狮子牡丹 ||| 是指 ||| 唐代西域狮子与帝国牡丹', 'relations': ['中文名', '类别', '是指', '品牌'], 'tag': 'O'}
# {'id': 323, 'question': 'STP战略是怎么做的啊？', 'answer': 'STP战略 ||| 步骤 ||| 市场细分、确定目标市场、定位', 'relations': ['中文名', '优势', '步骤', '属性'], 'tag': 'O'}
# {'id': 324, 'question': '请问液体疗法有什么作用？', 'answer': '液体疗法 ||| 治疗 ||| 脱水', 'relations': ['中文名', '治疗', '外文名', '给液途径'], 'tag': 'O'}
# {'id': 328, 'question': '地球构造的逃逸速度是多少？', 'answer': '地球构造 ||| 逃逸速度 ||| 11.2 km/s', 'relations': ['外文名', '质量', '表面温度', '别名', '平均密度', '赤经', '直径', '逃逸速度', '轨道倾角', '自转周期', '公转周期', '直径', '别称', '反照率', '离心率', '分类', '中文名', '逃逸速度', '平均密度', '半长轴', '赤纬'], 'tag': 'O'}
# {'id': 332, 'question': '闽安村的人均耕地有多少？', 'answer': '闽安村 ||| 人均耕地 ||| 0.98亩', 'relations': ['人均耕地', '人均收入', '人均纯收入', '中文名', '行政区类别'], 'tag': 'O'}
# {'id': 333, 'question': '你记得Tsubaki是哪天发售的吗？', 'answer': 'Tsubaki（开架式发妆品牌） ||| 发售日期 ||| 2006年3月', 'relations': ['出品公司', '发售日期', '产品类别', '别名', '别称', '中文名'], 'tag': 'O'}
# {'id': 334, 'question': '你知道白兔儿乖乖是哪个专辑里面的吗？', 'answer': "白兔儿乖乖 ||| 专辑名称 ||| 90'闹Now", 'relations': ['歌曲作词', '专辑名称', '歌手名称', '中文名'], 'tag': 'O'}
# {'id': 335, 'question': '1,2-环氧丁烷的CAS是什么', 'answer': '1,2-环氧丁烷 ||| CAS ||| 106-88-7', 'relations': ['外文名', '相对密度', '分子量', 'EINECS', '中文名', 'CAS', '分子式'], 'tag': 'O'}
# {'id': 336, 'question': 'windows域是怎么做的啊？', 'answer': 'windows域 ||| 步骤 ||| -运行输入dcpromo', 'relations': ['步骤', '中文名', '外文名', '安装条件', '具有', '外文名'], 'tag': 'O'}
# {'id': 338, 'question': '丁玲儿修为怎么样', 'answer': '丁玲儿 ||| 修为 ||| 九天武帝', 'relations': ['修为', '中文名', '登场作品'], 'tag': 'O'}
# {'id': 341, 'question': '你知道瑞典左翼党的意识形态是什么吗？', 'answer': '瑞典左翼党 ||| 意识形态 ||| 民主社会主义、生态社会主义', 'relations': ['领袖', '议会领袖', '意识形态', '外文名', '中文名'], 'tag': 'O'}
# {'id': 343, 'question': '中粮御岭湾是什么类别的建筑？', 'answer': '中粮御岭湾 ||| 建筑类别 ||| 独栋', 'relations': ['装修状况', '项目特色', '建筑类别', '中文名', '物业类别'], 'tag': 'O'}
# {'id': 346, 'question': '请说出外因论的要点是什么？', 'answer': '外因论 ||| 要点 ||| 外部力量的推动', 'relations': ['要点', '内容1', '内容', '中文名'], 'tag': 'O'}
# {'id': 347, 'question': '我想知道伊斯坦布尔赛道的地理位置是什么啊？', 'answer': '伊斯坦布尔赛道 ||| 地理 ||| 距离市中心约50公里', 'relations': ['设计', '地理', '中文名', '位于'], 'tag': 'O'}
# {'id': 350, 'question': '你知道Super star的名称是什么吗？', 'answer': 'Super star（韩国歌手专辑） ||| 专辑名称 ||| \xa0슈퍼스타 #3 - 서툰 고백', 'relations': ['专辑名称', '发行日期', '中文名', '专辑歌手'], 'tag': 'O'}
# {'id': 353, 'question': '第25届北京大学生电影节获得最佳男主角的详细资料有哪些？', 'answer': '第25届北京大学生电影节 ||| 最佳男主角 ||| 张震', 'relations': ['中文名', '主办单位', '最佳女主角', '最佳影片', '举办时间', '外文名', '颁奖地点', '最佳男主角'], 'tag': 'O'}
# {'id': 354, 'question': '台风丽琵的起编日期是什么时候', 'answer': '台风丽琵（2013年第4号台风） ||| 起编日期 ||| 2013年6月16日', 'relations': ['外文名', '中文名', '起编日期', 'JTWC数据', '停编日期', 'CMA数据', 'JMA数据', '国际编号'], 'tag': 'O'}
# {'id': 356, 'question': '请问Age35的作者是谁？', 'answer': 'Age35 ||| 漫画作者 ||| 柴门文', 'relations': ['漫画作者', '中文名', '漫画分类', '连载状态'], 'tag': 'O'}
# {'id': 358, 'question': '我很好奇毛里求斯航空的代码是什么？', 'answer': '毛里求斯航空 ||| 三字代码 ||| MAU', 'relations': ['两字代码', '创立时间', '中文名', '三字代码', '城市', '外文名', '创立时间', '平均机龄', '机队'], 'tag': 'O'}
# {'id': 359, 'question': 'DJF1型电力动车组的动力来自哪里', 'answer': 'DJF1型电力动车组 ||| 动力来源 ||| 电力', 'relations': ['别名', '中文名', '动力来源'], 'tag': 'O'}
# {'id': 363, 'question': '10·28南丹矿山冒顶事故有多少人员伤亡', 'answer': '10·28南丹矿山冒顶事故 ||| 人员伤亡 ||| 死亡2人，失联11人', 'relations': ['停止救援时间', '事故地点', '事发时间', '人员伤亡', '伤亡原因', '中文名'], 'tag': 'O'}
# {'id': 364, 'question': 'Dirty Deeds Done Dirt Cheap的本体是什么', 'answer': 'Dirty Deeds Done Dirt Cheap（漫画《JOJO的奇妙冒险》中替身能力） ||| 本体 ||| 法尼·瓦伦泰', 'relations': ['别名', '中文名', '登场作品', '外文名', '本体'], 'tag': 'O'}
# {'id': 365, 'question': '谁知道牛膝属是不是从外部引入的？', 'answer': '牛膝属 ||| 引种状况 ||| 非引种', 'relations': ['引种状况', '属', '目', '中文学名', '拉丁学名', '门', '亚纲', '分布区域', '界', '纲', '科'], 'tag': 'O'}
# {'id': 366, 'question': 'Blugirl主要负责什么工作', 'answer': 'Blugirl ||| 主要工作 ||| 设计制作针织服装', 'relations': ['外文名', '风格', '中文名', '创立时间', '主要工作'], 'tag': 'O'}
# {'id': 372, 'question': 'AK117是什么类型的武器', 'answer': 'AK117 ||| 武器类型 ||| 突击步枪', 'relations': ['武器价格', '外文名', '射击方式', '最大伤害', '俗称', '弹匣容量', '扫射精度', '最小伤害', '射速', '武器类型', '中文名', '稳定性', '开镜精度', '开始衰减距离', '射程', '最小伤害距离', '解锁等级'], 'tag': 'O'}
# {'id': 373, 'question': '8·8九寨沟地震的经度是多少？', 'answer': '8·8九寨沟地震 ||| 经度 ||| 东经103.82度', 'relations': ['纬度', '受灾人数', '发生时间', '地震烈度', '震源深度', '地震级别', '经度', '震源中心', '时间', '中文名', '伤亡人数'], 'tag': 'O'}
# {'id': 374, 'question': 'SCP-784-ARC的项目编号是多少？', 'answer': 'SCP-784-ARC ||| 项目编号 ||| SCP-784', 'relations': ['中文名', '项目等级', '项目编号', '外文名', '别名'], 'tag': 'O'}
# {'id': 377, 'question': '下坡风属于什么学科', 'answer': '下坡风 ||| 学科分支 ||| 大气', 'relations': ['学科分支', '相关术语', '中文名', '外文名'], 'tag': 'O'}
# {'id': 380, 'question': 'JABBERWOCKY最早出现在什么时候', 'answer': 'JABBERWOCKY（《爱丽丝梦游仙境》中的恶龙） ||| 最早出现 ||| 爱丽丝梦游仙境', 'relations': ['外文名', '同名漫画', '同名诗歌', '意思', '中文名', '最早出现'], 'tag': 'O'}
# {'id': 382, 'question': '请问国民革命军第四集团军管辖哪里？', 'answer': '国民革命军第四集团军 ||| 管辖 ||| 第四战区（1937年）', 'relations': ['改编时间', '下辖', '组成', '总司令', '中文名', '外文名', '存在时期', '管辖'], 'tag': 'O'}
# {'id': 384, 'question': '你知道下投式探空仪是哪个学科的分支吗', 'answer': '下投式探空仪 ||| 学科分支 ||| 大气探测学', 'relations': ['外文名', '中文名', '学科分支', '相关术语'], 'tag': 'O'}
# {'id': 386, 'question': '下南京靠什么谋生的', 'answer': '下南京 ||| 行当 ||| 红脸、花旦', 'relations': ['改编', '行当', '剧种', '首编', '中文名', '代表人物', '归属'], 'tag': 'O'}
# {'id': 388, 'question': '什么时候召开了中国共产党第十七次全国代表大会？', 'answer': '中国共产党第十七次全国代表大会 ||| 会议时间 ||| 2007年10月15日至21日', 'relations': ['会议重点', '会议报告', '会议时间', '会议简称', '会议地点'], 'tag': 'O'}
# {'id': 389, 'question': '谁知道国民革命军新编第一军打过哪些仗？', 'answer': '国民革命军新编第一军 ||| 参与战争 ||| 抗日战争、解放战争', 'relations': ['存在时间', '前身', '军歌', '存在时间', '别名', '主要功绩', '主要组成', '参与战争', '光荣称号', '中文名', '中文名', '别名', '外文名', '指挥官', '著名指挥官', '驻地'], 'tag': 'O'}
# {'id': 391, 'question': '压条的繁殖方式是什么？', 'answer': '压条（植物学术语） ||| 繁殖方式 ||| 压条繁殖', 'relations': ['中文名', '繁殖方式', '外文名', '术语', '繁殖类别'], 'tag': 'O'}
# {'id': 397, 'question': '你清楚龙门山风景名胜区的最佳旅游时间吗？', 'answer': '龙门山风景名胜区 ||| 最佳旅游时间 ||| 4月-11月份', 'relations': ['最佳旅游时间', '地址特点', '规划面积', '中文名', '外文名', '相关名人'], 'tag': 'O'}
# {'id': 398, 'question': '你认识三田都元帅的养父吗', 'answer': '三田都元帅 ||| 养父 ||| 田镌', 'relations': ['华诞', '养父', '生母', '养母', '象征', '典故', '出生地', '府邸', '中文名', '所属教派', '兄弟'], 'tag': 'O'}
# {'id': 399, 'question': '䢂的粤语拼音是什么', 'answer': '䢂 ||| 粤语拼音 ||| lip1', 'relations': ['四角', '仓颉', '笔顺', '粤语拼音', '五笔', '总笔画', '外文名', '简体部首', '郑码', '繁體部首', '中文名', '繁體字', '字形分析', '统一码'], 'tag': 'O'}
# {'id': 402, 'question': 'SQL服务器有什么理论基础', 'answer': 'SQL服务器 ||| 理论基础 ||| 关系模型', 'relations': ['中文名', '理论基础', '出现时间', '开发公司', '外文名', '所属学科'], 'tag': 'O'}
# {'id': 403, 'question': 'BOBO的住址在哪', 'answer': 'BOBO（《水木学堂》中的人物） ||| 住址 ||| 字母村(水木学堂)、水木村(水木学堂2)', 'relations': ['朋友', '登场作品', '中文名', '体色', '登场作品', '住址', '外文名'], 'tag': 'O'}
# {'id': 405, 'question': '你知道3C产业是什么时候出现的吗', 'answer': '3C产业 ||| 出现时期 ||| 90年代后期', 'relations': ['外文名', '地位', '中文名', '出现时期'], 'tag': 'O'}
# {'id': 406, 'question': '假面骑士：巅峰英雄Fourze的发售日期定在什么时候？', 'answer': '假面骑士：巅峰英雄Fourze ||| 发售日期 ||| 2011年12月01日', 'relations': ['中文名', '适宜年龄', '登场角色', '外文名', '发行地区', '别名', '发售日期'], 'tag': 'O'}
# {'id': 409, 'question': '你知道三星GT-S3870U的像素吗？', 'answer': '三星GT-S3870U ||| 摄像头 ||| 内置', 'relations': ['摄像头', '摄像头像素', '视频拍摄', '中文名'], 'tag': 'O'}
# {'id': 412, 'question': '寂寞在唱歌的风格是什么？', 'answer': '寂寞在唱歌（红莲妖姬所著小说） ||| 作品风格 ||| 正剧', 'relations': ['作品风格', '文章类型', '作品名称', '所属系列'], 'tag': 'O'}
# {'id': 415, 'question': '你知道圆觉寺的俗名是什么吗？', 'answer': '圆觉寺（河南叶县圆觉寺） ||| 俗名 ||| 草字庙', 'relations': ['中文名', '占地', '俗名', '地址'], 'tag': 'O'}
# {'id': 416, 'question': '请问鹰扬是什么意思？', 'answer': '鹰扬（汉语词汇） ||| 意为 ||| 威武貌', 'relations': ['意为', '出处', '中文名', '拼音'], 'tag': 'O'}
# {'id': 420, 'question': '95式自动步枪的总设计师是谁', 'answer': '95式自动步枪（军事武器枪械） ||| 总设计师 ||| 朵英贤', 'relations': ['简称', '中文名称', '枪管口径', '英文名称', '外文名', '研制时间', '类型', '国家', '服役时间', '定型时间', '所属国家', '国家', '简称', '中文名', '前型/级', '研发单位', '研制时间', '结构', '总设计师'], 'tag': 'O'}
# {'id': 421, 'question': '2010-2011中央电视台跨年盛典的直播平台是什么', 'answer': '2010-2011中央电视台跨年盛典 ||| 直播平台 ||| CCTV-1', 'relations': ['举办时间', '主题', '主持人', '直播平台', '主旨', '主题', '举办地点', '举办时间', '类别'], 'tag': 'O'}
# {'id': 422, 'question': '南通农场东西有多长？', 'answer': '南通农场 ||| 东西长 ||| 13.5公里', 'relations': ['方言', '东西长', '外文名', '经纬', '地处', '文化', '中文名', '民系', '省份', '总面积', '外文名'], 'tag': 'O'}
# {'id': 423, 'question': '新禁断之恋的漫画是谁画的啊？', 'answer': '新禁断之恋 ||| 漫画作者 ||| 大海十梦', 'relations': ['漫画作者', '漫画类型', '中文名', '解闷指数'], 'tag': 'O'}
# {'id': 424, 'question': '你知道102的十六进制是什么吗', 'answer': '102（自然数之一） ||| 十六进制 ||| 66', 'relations': ['八进制', '四进制', '倒数循环节', '十六进制', '三进制', '十二进制', '因数分解', '大写', '外文名', '二进制', '罗马数字', '中文名'], 'tag': 'O'}
# {'id': 425, 'question': '我想了解一下空心莓组它的形态特征是什么啊？', 'answer': '空心莓组 ||| 形态特征 ||| 直立或攀援', 'relations': ['出处', '属', '形态特征', '科', '拉丁学名', '中文学名', '界'], 'tag': 'O'}
# {'id': 426, 'question': '你们知道Le jardinier的副导演是谁吗', 'answer': 'Le jardinier ||| 副导演 ||| Richard Malbequi', 'relations': ['演员', '副导演', '外文名', '剪辑'], 'tag': 'O'}
# {'id': 433, 'question': '玻璃扯旗的繁殖方式是什么？', 'answer': '玻璃扯旗 ||| 繁殖方式 ||| 卵生', 'relations': ['目', '门', '科', '中文学名', '繁殖方式', '族', '界', '纲', '酸碱度', '别名', '亚门', '学名', '别称'], 'tag': 'O'}
# {'id': 434, 'question': '1961年恩多拉联合国DC-6坠毁事件是什么类型的飞机', 'answer': '1961年恩多拉联合国DC-6坠毁事件 ||| 飞机类型 ||| 道格拉斯DC-6B', 'relations': ['乘客', '幸存人数', '机组成员', '死亡人数', '飞机类型', '事故原因', '中文名', '注册号', '事故时间', '事故地点', '外文名'], 'tag': 'O'}
# {'id': 439, 'question': '请问东湖公园东西宽有多少米？', 'answer': '东湖公园（浙江省台州市临海市东湖公园） ||| 东西宽 ||| 约150米', 'relations': ['东西宽', '开放时间', '位于', '门票', '外文名', '交通', '南北长', '中文名'], 'tag': 'O'}
# {'id': 441, 'question': '请问安徽省康博粮油有限公司的主营业务有哪些？', 'answer': '安徽省康博粮油有限公司 ||| 主营业务 ||| 销售“康博”品牌系列食用油', 'relations': ['中文名', '主营业务'], 'tag': 'O'}
# {'id': 444, 'question': 'v的实力怎么样', 'answer': 'v（《东京喰种》中的喰种组织） ||| 实力 ||| 实力恐怖', 'relations': ['中文名', '势力', '外文名', '实力', '成员', '相关作品', '成员'], 'tag': 'O'}
# {'id': 446, 'question': '飞行机器有多少射程？', 'answer': '飞行机器 ||| 射程 ||| 近战/50', 'relations': ['外文名', '射程', '中文名', '出处', '类型'], 'tag': 'O'}
# {'id': 447, 'question': '青金石块有多亮？', 'answer': '青金石块 ||| 亮度 ||| 无', 'relations': ['可再生', '类别', '开采工具', '透明', '爆炸抗性', '掉落物', '可燃烧', '数据值', '可堆叠', '中文名', '外文名', '亮度'], 'tag': 'O'}
# {'id': 448, 'question': '谁知道三K党的意识形态？', 'answer': '三K党（美国民间排外团体） ||| 意识形态 ||| 种族主义', 'relations': ['组建时间', '国家', '特点', '外文名', '中文名', '口号', '意识形态', '定性'], 'tag': 'O'}
# {'id': 449, 'question': '京九铁路途径哪些城市', 'answer': '京九铁路 ||| 途经城市 ||| 北京、商丘、南昌、深圳、香港等', 'relations': ['北方省份', '南方省份', '车站数量', '设计速度', '铁路等级', '途经城市', '外文名', '线路长度', '车站数量', '开通日期', '运营速度', '中文名', '运营速度', '起止站点', '起止站点', '外文名', '途经城市'], 'tag': 'O'}
# {'id': 452, 'question': '113的大写怎么写', 'answer': '113（自然序数） ||| 大写 ||| 壹佰壹拾叁', 'relations': ['四进制', '罗马数字', '大写', '外文名', '三进制', '八进制', '十六进制', '中文名', '二进制', '十二进制', '倒数循环节'], 'tag': 'O'}
# {'id': 453, 'question': '谁知道HUAWEI Mate 20 X出厂时配了什么系统', 'answer': 'HUAWEI Mate 20 X ||| 出厂系统 ||| EMUI 9.0', 'relations': ['外文名', '运行内存', '屏幕尺寸', '中文名', 'CPU', '所属品牌', '产品类型', '出厂系统', '电池容量', '上市时间'], 'tag': 'O'}
# {'id': 455, 'question': '请问太阳的逃逸速度是多少？', 'answer': '太阳（太阳系中心的恒星） ||| 逃逸速度 ||| 617.7 km/s', 'relations': ['视星等', '质量', '距地距离', '赤经', '公转周期', '赤纬', '逃逸速度', '绝对星等', '别名', '中文名', '平均密度', '半径', '外文名', '自转周期', '直径', '表面温度', '分类'], 'tag': 'O'}
# {'id': 456, 'question': '你知道炸鸡排的成分是什么吗?', 'answer': '炸鸡排 ||| 营养成分 ||| 蛋白质', 'relations': ['工艺', '中文名', '主要食材', '分类', '口味', '分类', '营养成分'], 'tag': 'O'}
# {'id': 457, 'question': '告诉我118的四进制啊', 'answer': '118（自然数之一） ||| 四进制 ||| 1312', 'relations': ['三进制', '八进制', '大写', '因数分解', '十二进制', '倒数循环节', '四进制', '罗马数字', '十六进制', '中文名', '二进制'], 'tag': 'O'}
# {'id': 460, 'question': '中央民族工作会议是什么时候？', 'answer': '中央民族工作会议（1999年中央民族工作会议） ||| 会议时间 ||| 1999年9月29日至10月3日', 'relations': ['会议时间', '中文名', '会议地点'], 'tag': 'O'}
# {'id': 461, 'question': '互联网服务提供商的服务范围是什么？', 'answer': '互联网服务提供商 ||| 服务范围 ||| 一般企业及私人', 'relations': ['中文名', '服务范围', '缩写', '外文名'], 'tag': 'O'}
# {'id': 462, 'question': '中国民主建国会章程是哪个党派的', 'answer': '中国民主建国会章程 ||| 所属政党 ||| 中国民主建国会', 'relations': ['章数', '章数', '中文名', '条款', '通过时间', '所在国家', '通过时间', '所属政党'], 'tag': 'O'}
# {'id': 463, 'question': '索爱X10i的主屏尺寸是多大？', 'answer': '索爱X10i ||| 主屏尺寸 ||| 4英寸', 'relations': ['中文名', '电池容量', '上市时间', '主屏尺寸', '主屏分辨率', '外观设计', '机型尺寸'], 'tag': 'O'}
# {'id': 465, 'question': '你知道110的八进制吗', 'answer': '110（自然数之一） ||| 八进制 ||| 156', 'relations': ['别名', '大写', '三进制', '十六进制', '外文名', '中文名', '中文名', '四进制', '八进制', '因数分解', '十二进制', '二进制', '罗马数字', '倒数循环节'], 'tag': 'O'}
# {'id': 468, 'question': '我想知道利姓是谁发布的啊？', 'answer': '利姓 ||| 发布 ||| 南宁市、贵港市等', 'relations': ['发布', '郡望', '中文名', '主要渊源', '名人', '始祖', '外文名', '堂号'], 'tag': 'O'}
# {'id': 471, 'question': 'NI的元素符号是啥呀', 'answer': 'NI（化学元素） ||| 元素符号 ||| Ni', 'relations': ['物理性质', '原子序数', '外文名', '位置', '相对原子质量', '元素符号', '中文名'], 'tag': 'O'}
# {'id': 472, 'question': '请问广东省低碳产业技术协会在哪里办公？', 'answer': '广东省低碳产业技术协会 ||| 办公地点 ||| 广州新港西路135号', 'relations': ['办公地点', '中文名', '外文名', '成员', '会员单位'], 'tag': 'O'}
# {'id': 473, 'question': '一江两岸的装修情况怎么样', 'answer': '一江两岸 ||| 装修情况 ||| 毛坯', 'relations': ['装修情况', '绿化率', '楼盘地址', '容积率', '中文名'], 'tag': 'O'}
# {'id': 475, 'question': '1973年国际防止船舶造成污染公约是什么时候制定的', 'answer': '1973年国际防止船舶造成污染公约 ||| 制定时间 ||| 1973年10月8日至11月2日', 'relations': ['生效条件', '制定时间', '组织者', '中文名'], 'tag': 'O'}
# {'id': 480, 'question': '七伤拳是哪个门派的', 'answer': '七伤拳（金庸小说《倚天屠龙记》中的武功） ||| 所属门派 ||| 崆峒派', 'relations': ['修习条件', '出处', '修习者', '中文名', '所属门派'], 'tag': 'O'}
# {'id': 482, 'question': '城头山遗址东西多宽啊？', 'answer': '城头山遗址（江苏省镇江市句容县遗址） ||| 东西宽 ||| 约200米', 'relations': ['中文名', '东西宽', '位置', '南北长'], 'tag': 'O'}
# {'id': 483, 'question': '油焖冬笋具有什么营养价值？', 'answer': '油焖冬笋 ||| 营养价值 ||| 含有蛋白质、脂肪、钙、磷、铁', 'relations': ['中文名', '菜系', '地方特色菜', '营养价值'], 'tag': 'O'}
# {'id': 485, 'question': '你知道脊椎动物亚门的繁殖方式是什么吗？', 'answer': '脊椎动物亚门 ||| 繁殖方式 ||| 卵生、卵胎生或胎生。', 'relations': ['门', '拉丁学名', '中文学名', '亚门', '繁殖方式', '界', '纲', '别名'], 'tag': 'O'}
# {'id': 486, 'question': '你知道2019年香港人权与民主法案是什么时候签的吗', 'answer': '2019年香港人权与民主法案 ||| 签署时间 ||| 2019年11月27日', 'relations': ['制定方', '法案编号', '中文名', '签署时间', '外文名'], 'tag': 'O'}
# {'id': 488, 'question': '我想知道十八家晋史在第几章？', 'answer': '十八家晋史 ||| 章节 ||| 110卷', 'relations': ['分类', '记载年代', '九家', '流行时间', '章节', '中文名'], 'tag': 'O'}
# {'id': 490, 'question': 'FireBug占多大内存呀', 'answer': 'FireBug ||| 文件大小 ||| 1.1MB', 'relations': ['开发者', '操作系统', '文件大小', '原作者', '类型', '外文名'], 'tag': 'O'}
# {'id': 493, 'question': '永星村的农业户口有多少户啊？', 'answer': '永星村（广东省云浮市云安县镇安镇下辖村） ||| 农户 ||| 355户', 'relations': ['地址', '耕地面积', '农户', '中文名', '人口'], 'tag': 'O'}
# {'id': 495, 'question': '小开类似于什么？', 'answer': '小开（上海方言） ||| 类似 ||| 富二代', 'relations': ['中文名', '解释', '源于', '类似', '所属方言'], 'tag': 'O'}
# {'id': 501, 'question': '有多少队参加了2008年奥地利瑞士欧洲杯？', 'answer': '2008年奥地利瑞士欧洲杯 ||| 参赛队数 ||| 16支球队', 'relations': ['最佳射手', '参赛队数', '主办国家', '下一届', '中文名', '决赛场地', '举办时间', '比赛场数', '冠军', '上一届', '吉祥物', '外文名', '口号'], 'tag': 'O'}
# {'id': 503, 'question': '灌香肠有哪些营养成分？', 'answer': '灌香肠 ||| 营养成分 ||| 含有大量脂肪、蛋白、小麦淀粉、醣类以及微量铁、钙、钾、钠等成分', 'relations': ['原料', '营养成分', '质量标准', '类别', '中文名'], 'tag': 'O'}
# {'id': 505, 'question': '豪森花园平均多少钱？', 'answer': '豪森花园 ||| 均价 ||| 2620元/平方米', 'relations': ['中文名', '楼盘地址', '开发商', '均价', '楼盘名'], 'tag': 'O'}
# {'id': 506, 'question': '魂之挽歌的冷却时间是多少？', 'answer': '魂之挽歌 ||| 冷却时间 ||| 120/110/100秒', 'relations': ['所属分类①', '曲调', '中文名', '所属分类②', '魔法消耗', '冷却时间', '施法时间'], 'tag': 'O'}
# {'id': 507, 'question': '你知道关东山地东西有多长吗？', 'answer': '关东山地 ||| 东西长 ||| 60公里', 'relations': ['位置', '东西长', '南北长', '中文名', '纵贯'], 'tag': 'O'}
# {'id': 508, 'question': '你知道唢呐的俗称是什么吗？', 'answer': '唢呐 ||| 俗名 ||| 喇叭', 'relations': ['应用学科', '成熟时间', '代表人物', '成熟时间', '起源时间', '适用领域', '应用学科', '中文名', '代表作品', '俗名', '代表作品', '代表作品', '应用学科', '音色', '别名', '中国唢呐之乡', '外文名'], 'tag': 'O'}
# {'id': 512, 'question': 'Ubt的原子量是多少', 'answer': 'Ubt ||| 原子量 ||| 328u（预测）', 'relations': ['元素表区块', '沸点', '外文名', '水溶性', '元素表位置', '熔点', '密度', '原子序数', '原子量', '外观'], 'tag': 'O'}
# {'id': 516, 'question': '东北野战军第三纵队的司令员叫什么', 'answer': '东北野战军第三纵队 ||| 司令员 ||| 程世才', 'relations': ['隶属', '外文名', '中文名', '司令员'], 'tag': 'O'}
# {'id': 517, 'question': '闪光之追放者的罕贵度是什么？', 'answer': '闪光之追放者 ||| 罕贵度 ||| 银字R', 'relations': ['星级', '外文名', '中文名', '罕贵度'], 'tag': 'O'}
# {'id': 518, 'question': '802.16e实现了什么技术？', 'answer': '802.16e ||| 实现 ||| 一定的移动性', 'relations': ['实现', '中文名', '主要差别', '适应'], 'tag': 'O'}
# {'id': 520, 'question': '中华基督教青年会全国协会是在哪里注册的呀', 'answer': '中华基督教青年会全国协会 ||| 注册机构 ||| 民政部', 'relations': ['组织状态', '法定代表人', '注册机构', '外文名', '社会信用代码', '登记证号', '业务主管', '中文名'], 'tag': 'O'}
# {'id': 521, 'question': '告诉我中国传统文化的开课时间被', 'answer': '中国传统文化（西安交通大学提供的课程） ||| 开课时间 ||| 2015年秋冬（首次）', 'relations': ['开课时间', '授课平台', '提供院校', '中文名', '授课教师', '类别'], 'tag': 'O'}
# {'id': 522, 'question': '你知道Sg的元素符号是什么呢', 'answer': 'Sg（元素符号） ||| 元素符号 ||| Sg', 'relations': ['族', '外文名', '元素符号', '中文名', '原子序数', '原子量', '周期'], 'tag': 'O'}
# {'id': 524, 'question': '三钵罗底的统治时间有多久', 'answer': '三钵罗底 ||| 统治时间 ||| 公元前224年—公元前215年', 'relations': ['统治时间', '外文名', '所处时代', '中文名'], 'tag': 'O'}
# {'id': 525, 'question': '爱尔兰皇家科学院是什么类型的机构？', 'answer': '爱尔兰皇家科学院 ||| 机构类型 ||| 自然科学人文和社会科学学术机构', 'relations': ['中文名', '院士', '外文名', '机构类型'], 'tag': 'O'}
# {'id': 528, 'question': '证券从业资格预约式考试考试的时间由谁确定？', 'answer': '证券从业资格预约式考试 ||| 考试时间 ||| 各月份不等', 'relations': ['中文名', '上级单位', '成绩查询', '开始时间', '考试时间', '类型'], 'tag': 'O'}
# {'id': 529, 'question': '请问Puppy Linux是什么时候发布的？', 'answer': 'Puppy Linux ||| 发布 ||| 2008年10月6日', 'relations': ['软件更新', '主要变化', '商标', '发布', '中文名'], 'tag': 'O'}
# {'id': 531, 'question': '乐2 Pro的摄像头像素怎么样？', 'answer': '乐2 Pro ||| 摄像头 ||| 前8MP/后21MP', 'relations': ['中文名', '处理器', '摄像头', '屏幕', '上市时间', '发布时间', '外文名', '分辨率', '手机硬件名'], 'tag': 'O'}
# {'id': 541, 'question': '保利世界贸易中心的轨道交通属于哪条线？', 'answer': '保利世界贸易中心 ||| 轨道交通 ||| 8号线', 'relations': ['项目位置', '行政区域', '建筑类型', '轨道交通', '区域板块', '中文名'], 'tag': 'O'}
# {'id': 544, 'question': '严正是什么时候被免职的', 'answer': '严正（滁州市人大常委会民宗侨外工作委员会原主任） ||| 免职时间 ||| 2017年4月27日', 'relations': ['任职', '中文名', '免职时间', '任命时间'], 'tag': 'O'}
# {'id': 545, 'question': '谁知道卷心菜投手能射多远呀？', 'answer': '卷心菜投手 ||| 射程 ||| 正前方一整行', 'relations': ['别名', '登场作品', '阳光', '中文名', '原型', '射程', '外文名', '登场作品', '攻击'], 'tag': 'O'}
# {'id': 547, 'question': '你知道杰尔系统属于什么公司啊？', 'answer': '杰尔系统 ||| 隶属公司 ||| 美国杰尔系统有限公司', 'relations': ['中文名', '隶属公司', '经营范围', '外文名'], 'tag': 'O'}
# {'id': 550, 'question': '360手机N4的运行内存是多少', 'answer': '360手机N4 ||| 运行内存 ||| 4GB', 'relations': ['网络制式', '运行内存', '屏幕大小', '上市时间', '中文名', '产品售价', '处理器', '操作系统', '特色功能', '相机像素', '手机尺寸', '机身储存', '发布时间', '电池容量'], 'tag': 'O'}
# {'id': 552, 'question': '北京群众艺术馆的地址在哪？', 'answer': '北京群众艺术馆 ||| 展馆位置 ||| 北京市海淀区上园村3号知行大厦5层', 'relations': ['人员', '展馆位置', '地址', '展馆名称'], 'tag': 'O'}
# {'id': 553, 'question': '西北民族研究所属于什么院校？', 'answer': '西北民族研究所 ||| 所属院校 ||| 西北民族学院', 'relations': ['现设', '研究室', '中文名', '所属院校'], 'tag': 'O'}
# {'id': 555, 'question': '你知道中华周易文化协会是什么服务范围吗？', 'answer': '中华周易文化协会 ||| 服务范围 ||| 周易文化推广、研究、交流', 'relations': ['副会长', '协会性质', '外文名', '服务范围', '中文名', '名誉会长', '协会宗旨', '协会网站', '会长'], 'tag': 'O'}
# ...
# {'id': 1798, 'question': '你知道半自动手枪一般都被指代成什么吗？', 'answer': '半自动手枪 ||| 指代 ||| 仅能自动装填弹药的单发手枪', 'relations': ['出现时间', '区别', '中文名', '别名', '地点', '指代'], 'tag': 'O'}
# {'id': 1802, 'question': '药品生产许可证是什么单位发布的？', 'answer': '药品生产许可证 ||| 发布 ||| 国家食品药品监督管理局', 'relations': ['中文名', '外文名', '发布', '有效期'], 'tag': 'O'}
# {'id': 1804, 'question': '丁卡族是黄种人、白种人还是黑人呀', 'answer': '丁卡族 ||| 人种 ||| 身材最高的民族', 'relations': ['人种', '中文名', '人口', '领地'], 'tag': 'O'}
# {'id': 1807, 'question': '台风万宜是什么时候停编的', 'answer': '台风万宜（2013年第18号强热带风暴） ||| 停编日期 ||| 2013年9月16日', 'relations': ['生成时间', '编号', '名字来源', '中文名', '外文名', '生成位置', '名字意义', '伤亡情况', '停编日期'], 'tag': 'O'}
# {'id': 1808, 'question': '驾驶员理论考试的考试时间是什么时候？', 'answer': '驾驶员理论考试 ||| 考试时间 ||| 45分钟', 'relations': ['考试题目', '考试时间', '中文名', '考试类型', '考试辅助', '外文名'], 'tag': 'O'}
# {'id': 1809, 'question': '我想知道抗癌药可以治疗什么？', 'answer': '抗癌药 ||| 治疗 ||| 治疗肿瘤', 'relations': ['分类', '治疗', '抗癌药物', '外文名', '药物制剂', '中文名'], 'tag': 'O'}
# {'id': 1811, 'question': 'RecA蛋白类似哪本书？', 'answer': 'RecA蛋白 ||| 类似 ||| 纤维', 'relations': ['通过', '中文名', '类似', '分子量'], 'tag': 'O'}
# {'id': 1815, 'question': '中国共产党第十八届中央委员会第七次全体会议在哪个时间段举行？', 'answer': '中国共产党第十八届中央委员会第七次全体会议 ||| 会议时间 ||| 2017年10月11日-14日', 'relations': ['会议时间', '会议主持', '中文名', '外文名', '会议地点'], 'tag': 'O'}
# {'id': 1816, 'question': '你了解机甲士兵的罕贵度吗？', 'answer': '机甲士兵 ||| 罕贵度 ||| 银碎SER', 'relations': ['外文名', '罕贵度', '中文名', '星级', '别名', '属性'], 'tag': 'O'}
# {'id': 1819, 'question': '统计从业资格证考试的时间由谁确定？', 'answer': '统计从业资格证 ||| 考试时间 ||| 120分', 'relations': ['考试科目', '考试时间', '外文名', '考试日期', '中文名', '合格标准'], 'tag': 'O'}
# {'id': 1821, 'question': '你知道任烨是什么级别的医生吗', 'answer': '任烨（执业医师） ||| 医师级别 ||| 执业医师', 'relations': ['医师级别', '执业地点', '执业类别', '执业证书编码', '执业范围'], 'tag': 'O'}
# {'id': 1822, 'question': 'SOHO北京公馆什么时候交房', 'answer': 'SOHO北京公馆 ||| 交房时间 ||| 2008年11月', 'relations': ['物业费', '开盘时间', '绿化率', '均价', '楼盘地址', '户型面积', '板块', '开发商', '预售许可证', '物业类别', '交房时间', '城区', '建筑结构', '物业公司', '楼盘名', '占地面积', '销售状态', '建筑面积', '城区', '总户数', '容积率', '中文名', '城市', '产权年限'], 'tag': 'O'}
# {'id': 1823, 'question': '2016年全国大众创业万众创新活动周的活动范围在哪', 'answer': '2016年全国大众创业万众创新活动周 ||| 活动范围 ||| 全国', 'relations': ['中文名', '活动范围', '主题', '活动时间'], 'tag': 'O'}
# {'id': 1826, 'question': '18型客车是哪个国家生产的', 'answer': '18型客车 ||| 生产国 ||| 民主德国、中国', 'relations': ['外文名', '生产国', '生产厂商2', '生产厂商1', '型号2', '生产厂商1', '型号1', '中文名', '生产国', '外文名', '制造年份', '衍生型'], 'tag': 'O'}
# {'id': 1828, 'question': '徐夫人之子是谁？', 'answer': '徐夫人（三国吴宗室孙翊之妻） ||| 子 ||| 孙松', 'relations': ['主要成就', '丈夫', '别称', '所处时代', '民族族群', '子', '本名', '别名'], 'tag': 'O'}
# {'id': 1829, 'question': '请问瓦版的目的是什么？', 'answer': '瓦版 ||| 主旨 ||| 报道新闻', 'relations': ['中文名', '内容', '主旨', '发行日期'], 'tag': 'O'}
# {'id': 1830, 'question': '请问三里亭社区的绿化面积多大', 'answer': '三里亭社区（杭州市闸弄口街道三里亭社区） ||| 绿化面积 ||| 9000平方米', 'relations': ['中文名', '绿化面积', '总户数', '总面积'], 'tag': 'O'}
# {'id': 1838, 'question': '自然电位测井主要由什么应用？', 'answer': '自然电位测井 ||| 主要应用 ||| 找出渗透性地层', 'relations': ['外文名', '学科', '中文名', '影响因素', '主要应用', '测量内容'], 'tag': 'O'}
# {'id': 1839, 'question': '你可以阐述一下隐性知识显性化吗？', 'answer': '隐性知识显性化 ||| 阐述 ||| 在行动中所蕴含的未被表述的知识', 'relations': ['中文名', '阐述', '类别', '相关'], 'tag': 'O'}
# {'id': 1840, 'question': '上海市徐汇区教育局的地址在哪呀', 'answer': '上海市徐汇区教育局 ||| 单位地址 ||| 上海市漕溪北路336号', 'relations': ['中文名', '单位地址', '主要职责', '类型'], 'tag': 'O'}
# {'id': 1849, 'question': '丮的UniCode编码是什么', 'answer': '丮 ||| UniCode ||| CJK', 'relations': ['笔顺编号', '拼音', '字码', '部首', '四角号码', '五笔86', '总笔画', '外文名', '拼音', '郑码', '中文名', '统一汉字', '五笔98', '五笔', 'UniCode', '笔顺', '仓颉'], 'tag': 'O'}
# {'id': 1850, 'question': '我们有没有引种栽培三裂蛇葡萄呢', 'answer': '三裂蛇葡萄 ||| 是否引种栽培 ||| 非人工引种栽培', 'relations': ['目', '种', '是否中国特有', '海拔区间', '纲', '科', '属', '分布区域', '门', '外文名', '中文名', '别名', '是否引种栽培', '界'], 'tag': 'O'}
# {'id': 1852, 'question': 'androp的登场日期是什么时候', 'answer': 'androp ||| 登场日期 ||| 2009年', 'relations': ['登场日期', '外文名'], 'tag': 'O'}
# {'id': 1853, 'question': '信息港经营哪些业务？', 'answer': '信息港 ||| 主营业务 ||| 宽带接入', 'relations': ['最好', '组成', '主营业务', '中文名'], 'tag': 'O'}
# {'id': 1855, 'question': '第71届联合国大会是什么时候开幕的？', 'answer': '第71届联合国大会 ||| 开幕时间 ||| 2016年9月13日', 'relations': ['中文名', '开幕时间', '成果', '地点'], 'tag': 'O'}
# {'id': 1857, 'question': '你知道1994年关税与贸易总协定是什么时候召开的吗', 'answer': '1994年关税与贸易总协定 ||| 召开时间 ||| 1944年7月', 'relations': ['地点', '召开时间', '外文名', '中文名'], 'tag': 'O'}
# {'id': 1860, 'question': '你知道上海马桥遗址属于哪个年代吗', 'answer': '上海马桥遗址 ||| 所属时代 ||| 新石器时代至商', 'relations': ['批准单位', '编号', '占地面积', '中文名', '所属时代', '所处地区', '保护级别'], 'tag': 'O'}
# {'id': 1863, 'question': '谁知道生命周期评估主要应用于什么地方？', 'answer': '生命周期评估 ||| 主要应用 ||| 改善其环境问题决策提供支持', 'relations': ['中文名', '主要应用', '外文名', '简称'], 'tag': 'O'}
# {'id': 1864, 'question': '你知道DASEIN的音译是什么', 'answer': 'DASEIN ||| 音译 ||| 达赞', 'relations': ['成员', '外文名', '性质', '中文名', '组成时间', '性质', '地区', '音译'], 'tag': 'O'}
# {'id': 1865, 'question': '中国南极长城站位于哪里？', 'answer': '中国南极长城站 ||| 展馆位置 ||| 南极洲南设得兰群岛乔治王岛南端', 'relations': ['揭牌时间', '展馆位置', '海拔高度', '展馆名称', '建筑面积', '开工时间', '竣工时间'], 'tag': 'O'}
# {'id': 1867, 'question': 'AI驱动器是谁制造的', 'answer': 'AI驱动器 ||| 制造者 ||| 泽神玲奈', 'relations': ['外文名', '音效CV', '使用者', '中文名', '制造者', '登场作品'], 'tag': 'O'}
# {'id': 1868, 'question': '你会怎么阐述核反应堆厂房？', 'answer': '核反应堆厂房 ||| 阐述 ||| 核电站主工艺厂房的外部屏蔽结构', 'relations': ['相关', '类别', '阐述', '中文名'], 'tag': 'O'}
# {'id': 1876, 'question': '你知道皂荚属是哪种引种状况吗？', 'answer': '皂荚属 ||| 引种状况 ||| 非引种', 'relations': ['科', '模式种', '引种状况', '拉丁学名', '族', '目', '门', '亚目', '亚纲', '命名者及年代', '属', '界', '分布区域', '纲', '中文学名', '亚科'], 'tag': 'O'}
# {'id': 1881, 'question': '佩皮尼昂机场的三字代码是什么？', 'answer': '佩皮尼昂机场 ||| 三字代码 ||| PGF', 'relations': ['中文名', '四字代码', '三字代码', '外文名'], 'tag': 'O'}
# {'id': 1882, 'question': 'EMCC的登记单位在那', 'answer': 'EMCC（欧洲导师与教练协会） ||| 登记单位 ||| 比利时注册', 'relations': ['登记单位', '中文名', '属性', '外文名', '社团地址'], 'tag': 'O'}
# {'id': 1884, 'question': '酹江亭是什么时候开工和完成的？', 'answer': '酹江亭 ||| 建筑时间 ||| 明代', 'relations': ['修缮时间', '中文名', '来源', '建筑时间'], 'tag': 'O'}
# {'id': 1885, 'question': '三亚市图书馆现在谁是馆长', 'answer': '三亚市图书馆 ||| 现任馆长 ||| 周翔', 'relations': ['现任馆长', '馆舍类型', '地址', '简称', '中文名', '主管部门', '外文名', '主要奖项', '藏书总量', '属性', '建馆时间'], 'tag': 'O'}
# {'id': 1886, 'question': '䨻的UniCode编码是什么', 'answer': '䨻 ||| UniCode ||| 4A3B', 'relations': ['统一码', '部外笔画', 'UniCode', '含义', '中文名', '仓颉', '拼音', '五笔', '四角号码', '笔画', '统一汉字', '部首'], 'tag': 'O'}
# {'id': 1889, 'question': '你知道帕甘岛的陆地面积有多少吗？', 'answer': '帕甘岛 ||| 陆地面积 ||| 49平方公里', 'relations': ['中文名', '喷发时间', '陆地面积', '外文名', '地点'], 'tag': 'O'}
# {'id': 1891, 'question': '你知道婚神星的逃逸速度是多少吗？', 'answer': '婚神星 ||| 逃逸速度 ||| 0.18 km/s', 'relations': ['中文名', '公转周期', '离心率', '远日点', '平近点角', '编号', '分类', '直径', '质量', '表面温度', '别称', '自转周期', '小行星分类', '表面重力', '近日点', '外文名', '升交点经度', '升交点经度', '自转周期', '绝对星等', '发现者', '轨道倾角', '发现时间', '质量', '轨道倾角', '小行星类型', '半长轴', '反照率', '别名', '平近点角', '平均运行速度', '绝对星等', '角直径', '逃逸速度', '平均密度', '视星等'], 'tag': 'O'}
# {'id': 1900, 'question': '谁知道11·23小笠原群岛地震是多少级？', 'answer': '11·23小笠原群岛地震 ||| 震级 ||| 6.2级', 'relations': ['发生时间', '震级', '中文名', '地点'], 'tag': 'O'}
# {'id': 1901, 'question': '“五四”运动一百周年是什么类型的邮票', 'answer': '“五四”运动一百周年 ||| 邮票类型 ||| 纪念邮票', 'relations': ['发行日期', '全套枚数', '邮票类型', '中文名', '外文名', '邮票志号'], 'tag': 'O'}
# {'id': 1903, 'question': '你知道Gladius是什么时候出现的吗', 'answer': 'Gladius（罗马短剑） ||| 出现时期 ||| 罗马帝国统治时期', 'relations': ['出现时期', '发源地', '别名', '分类', '材质', '外文名'], 'tag': 'O'}
# {'id': 1905, 'question': '台风圣帕有多少人遇难？', 'answer': '台风圣帕（2007年第8号超强台风） ||| 死亡人数 ||| 至少39人', 'relations': ['CMA数据', '外文名', '消散时间', '形成时间', '最高风速', '概况', '影响地区', '中文名', '死亡人数'], 'tag': 'O'}
# {'id': 1906, 'question': '万科金域华府的交房时间是什么时候', 'answer': '万科金域华府（厦门万科金域华府） ||| 交房时间 ||| 2013-03-31', 'relations': ['均价', '绿化率', '开发商', '开盘时间', '中文名', '建筑形式', '交房时间', '物业类别', '物业公司', '容积率', '楼盘地址', '物业费', '城区', '装修情况'], 'tag': 'O'}
# {'id': 1907, 'question': 'A-20攻击机是什么时候退役的', 'answer': 'A-20攻击机 ||| 退役时间 ||| 1949年（美国空军）', 'relations': ['退役时间', '中文名', '研制单位', '国家', '服役时间', '研制时间', '首飞时间', '前型/级', '次型/级', '外文名', '定型时间'], 'tag': 'O'}
# {'id': 1908, 'question': '你知道现在谁是中国人民大学广播台的台长', 'answer': '中国人民大学广播台 ||| 现任台长 ||| 吕金蔚', 'relations': ['现届数', '机构组成', '简称', '中文名', '著名活动', '外文名', '地区', '复台时间', '直属部门', '现任台长'], 'tag': 'O'}
# {'id': 1909, 'question': '第六届全国残运会什么时候开幕？', 'answer': '第六届全国残运会 ||| 开幕时间 ||| 2003年9月16日', 'relations': ['中文名', '时间', '特点', '等等', '比赛时间', '开幕时间'], 'tag': 'O'}
# {'id': 1911, 'question': '69有什么品牌口号', 'answer': '69（情趣品牌） ||| 品牌口号 ||| 换个姿势爱', 'relations': ['品牌宗旨', '所属行业', '英文名称', '中文名', '品牌口号', '中文名称', '所属公司', '外文名'], 'tag': 'O'}
# {'id': 1914, 'question': '2011年诺贝尔奖的创办机构是什么', 'answer': '2011年诺贝尔奖 ||| 创办机构 ||| 诺贝尔奖基金会', 'relations': ['外文名', '颁奖地点', '奖项类型', '奖项地区', '颁奖时间', '奖项数', '创办机构', '中文名'], 'tag': 'O'}
# {'id': 1918, 'question': '你知道SKA恩纳吉亚属于哪个联赛吗', 'answer': 'SKA恩纳吉亚 ||| 所属联赛 ||| 俄罗斯足球甲级联赛', 'relations': ['中文名', '所属联赛'], 'tag': 'O'}
# {'id': 1922, 'question': '你知道蝶豆属的引种状况吗？', 'answer': '蝶豆属 ||| 引种状况 ||| 非引种', 'relations': ['中文名', '引种状况', '科', '中文学名', '界', '拉丁学名', '分布量'], 'tag': 'O'}
# {'id': 1923, 'question': '严皓属于什么境界的', 'answer': '严皓（玄幻小说《斗破苍穹》的角色） ||| 境界 ||| 斗灵', 'relations': ['中文名', '境界'], 'tag': 'O'}
# {'id': 1924, 'question': '请问阿Q与孔乙己的作者是谁？', 'answer': '阿Q与孔乙己 ||| 作家 ||| 作家陈涌泉', 'relations': ['类型', '中文名', '作家', '地区'], 'tag': 'O'}
# {'id': 1925, 'question': '鹰击81有多少射程？', 'answer': '鹰击81 ||| 射程 ||| 8至50公里', 'relations': ['美誉', '射程', '中文名', '类型'], 'tag': 'O'}
# {'id': 1927, 'question': '一品红是什么时候采集的', 'answer': '一品红（中药） ||| 采集时间 ||| 全年', 'relations': ['毒性', '别称', '科', '用量', '属', '目', '界', '纲', '中文学名', '别名', '采集时间', '门', '种'], 'tag': 'O'}
# {'id': 1930, 'question': '请问中国500最具价值品牌的首次发行时间是哪天？', 'answer': '中国500最具价值品牌 ||| 首发时间 ||| 2004年', 'relations': ['外文名', '首发时间', '发布机构', '属性', '中文名'], 'tag': 'O'}
# {'id': 1933, 'question': '在粤语中，中山八路要怎么拼啊', 'answer': '中山八路 ||| 粤语拼音 ||| Zungsaan 8 Lou', 'relations': ['普通话拼音', '普通话拼音', '方向', '中文名', '外文名', '命名时间', '粤语拼音'], 'tag': 'O'}
# {'id': 1934, 'question': '请问九子鬼母因何得名？', 'answer': '九子鬼母（佛经里记载的九子鬼母） ||| 得名原因 ||| 每日产九鬼', 'relations': ['外文名', '中文名', '别名', '得名原因'], 'tag': 'O'}
# {'id': 1935, 'question': '抗抑郁药可以治疗什么？', 'answer': '抗抑郁药 ||| 治疗 ||| 情绪抑郁为突出症状的精神疾病', 'relations': ['治疗', '分类', '外文名', '中文名'], 'tag': 'O'}
# {'id': 1936, 'question': '康馨雅苑多少钱一平方米？', 'answer': '康馨雅苑 ||| 均价 ||| 2500元/平方米', 'relations': ['均价', '建筑面积', '占地面积', '中文名'], 'tag': 'O'}
# {'id': 1939, 'question': '天长军的意思是什么啊？', 'answer': '天长军 ||| 词意 ||| 南宋行政区划名', 'relations': ['词性', '中文名', '类别', '词意'], 'tag': 'O'}
# {'id': 1940, 'question': '谁能告诉我深圳湾大酒店具体地址是哪里？', 'answer': '深圳湾大酒店 ||| 酒店地址 ||| 深南大道华侨城', 'relations': ['中文名', '特点', '酒店地址', '开业时间', '开业时间'], 'tag': 'O'}
# {'id': 1944, 'question': '甜姐新嫁娘的漫画是谁画的啊？', 'answer': '甜姐新嫁娘 ||| 漫画作者 ||| 水上航', 'relations': ['漫画分类', '漫画作者', '中文名', '连载状态'], 'tag': 'O'}
# {'id': 1947, 'question': '六分仪座的最佳观测纬度是什么', 'answer': '六分仪座 ||| 最佳观测纬度 ||| +80°和−80°之间', 'relations': ['邻接星座', '完全可见区域', '属格', '最佳观测时间', '最佳观测纬度', '面积排名', '拉丁缩写', '亮星数目', '最亮星', '象征物', '赤经', '赤纬', '星座面积', '最亮星视星等', '流星雨', '拉丁学名', '天体名称'], 'tag': 'O'}
# {'id': 1949, 'question': '公共关系公司是什么类型的机构？', 'answer': '公共关系公司 ||| 机构类型 ||| 社会机构', 'relations': ['机构类型', '中文名', '隶属行业', '外文名'], 'tag': 'O'}
# {'id': 1951, 'question': '你知道上官元让修为如何', 'answer': '上官元让 ||| 修为 ||| 灵空境', 'relations': ['其他名称', '小说作者', '角色', '别名', '中文名', '登场作品', '修为'], 'tag': 'O'}
# {'id': 1952, 'question': '58型巡洋舰属于什么舰型', 'answer': '58型巡洋舰 ||| 舰型 ||| 导弹巡洋舰', 'relations': ['英文名称', '研制时间', '次型/级', '国家', '定型时间', '服役时间', '北约名称', '外文名', '中文名称', '前型/级', '建造数量', '中文名', '舰型', '服役情况', '本国名称'], 'tag': 'O'}
# {'id': 1955, 'question': '请问PCS1900适用于哪些地区', 'answer': 'PCS1900 ||| 适用地区 ||| 北美地区', 'relations': ['适用手机', '适用地区', '适用用户', '适用领域', '支持频段', '中文名'], 'tag': 'O'}
# {'id': 1956, 'question': '你知道㫃的字形结构吗', 'answer': '㫃 ||| 字形结构 ||| 左右结构', 'relations': ['部首', '字形结构', '拼音', '中文名', '仓颉', '四角号码', '五笔', '统一码'], 'tag': 'O'}
# {'id': 1957, 'question': '回溯分析是什么时候被观测到的？', 'answer': '回溯分析 ||| 发现 ||| 全网络的通讯记录与监控', 'relations': ['追踪', '解释', '中文名', '发现'], 'tag': 'O'}
# {'id': 1960, 'question': '麻烦你告诉我一下北京月亮河庭院酒店具体地址？', 'answer': '北京月亮河庭院酒店 ||| 酒店地址 ||| 北京市密云溪翁庄镇政府东侧', 'relations': ['酒店地址', '开业时间', '中文名', '装修时间'], 'tag': 'O'}
# {'id': 1961, 'question': '请问RPD的射程是多少？', 'answer': 'RPD（网游《使命召唤OL》中的武器） ||| 射程 ||| 93', 'relations': ['稳定性', '射击模式', '机动性', '伤害（爆头）', '中文名', '开镜精度', '射速', '解锁等级', '弹匣容量', '射程', '扫射精度', '武器价格', '武器类型'], 'tag': 'O'}
# {'id': 1965, 'question': '有人知道中国共产党第十二次全国代表大会是什么时候吗？', 'answer': '中国共产党第十二次全国代表大会 ||| 会议时间 ||| 1982年9月1日至11日', 'relations': ['时间', '会议通过', '代表人数', '地点', '会议时间', '中文名', '会议地点', '大会报告'], 'tag': 'O'}
# {'id': 1967, 'question': '你知道HTC One mini有多大运行内存吗', 'answer': 'HTC One mini ||| 运行内存 ||| 1GB', 'relations': ['电池容量', '外文名', '像素', '中文名', '屏幕尺寸', '屏幕分辨率', 'CPU', '运行内存'], 'tag': 'O'}
# {'id': 1970, 'question': '对M78来说，有哪些象征物呢', 'answer': 'M78 ||| 象征物 ||| 猎户座', 'relations': ['亮星数目', '最佳观测时间', '赤经', '拉丁名', '天体名称', '赤经', '象征物', '邻接星座', '赤纬', '最佳观测纬度', '赤纬', '拉丁学名'], 'tag': 'O'}
# {'id': 1971, 'question': '1,4-二氧六环的EINECS号是什么', 'answer': '1,4-二氧六环 ||| EINECS号 ||| 204-661-8', 'relations': ['初沸点和沸程(℃)', 'CAS号', 'MDL号', '与水共沸点', '中文名', 'InChI', 'EINECS号', '熔点/凝固点(℃)', 'RTECS号', '别名', '英文名称', '分子量', '相对密度(水=1)', '中文名称', 'PubChem号', 'BRN号', '分子式', '英文别名', '外文名'], 'tag': 'O'}
# {'id': 1972, 'question': '请问蟠龙菜的俗名是什么？', 'answer': '蟠龙菜（传统菜肴） ||| 俗名 ||| 剁菜', 'relations': ['俗名', '相关标准', '外文名', '中文名', '主要食材', '风行地区', '口味', '分类', '起源时间'], 'tag': 'O'}
# {'id': 1973, 'question': '激光是什么时候被观测到的？', 'answer': '激光（受激辐射光放大） ||| 发现 ||| 1916年', 'relations': ['首次激发', '发现', '中文名', '释义', '外文名'], 'tag': 'O'}
# {'id': 1976, 'question': 'GESS的愿景是什么', 'answer': 'GESS ||| 愿景 ||| 为改善全球人们的健康生活而努力', 'relations': ['愿景', '创立时间', '英文名称', '所属行业', '品牌总部', '外文名', '理念'], 'tag': 'O'}
# {'id': 1978, 'question': '请问五色经幡的目的是什么？', 'answer': '五色经幡 ||| 主旨 ||| 慈悲为怀，普渡众生', 'relations': ['象征', '中文名', '主旨', '颜色'], 'tag': 'O'}
# {'id': 1979, 'question': 'Aghanim的神杖的总价要多少钱', 'answer': 'Aghanim的神杖 ||| 总价 ||| 4200/5800', 'relations': ['合成需要', '总价', '其他名称', '外文名', '总价', '别名', '出处', '中文名'], 'tag': 'O'}
# {'id': 1980, 'question': '哪些国家在使用88式狙击步枪啊', 'answer': '88式狙击步枪 ||| 使用国家 ||| 中国', 'relations': ['枪管', '口径', '服役时间', '全重', '有效射程', '中文名称', '弹匣容量', '英文名称', '中文名', '全长', '外文名', '别名', '国家', '使用国家'], 'tag': 'O'}
# {'id': 1981, 'question': 'Paint My Love的资源类型是什么？', 'answer': 'Paint My Love ||| 资源类型 ||| MP3!', 'relations': ['资源类型', '中文名', '外文名', '别名', '地区：'], 'tag': 'O'}
# {'id': 1983, 'question': '东湖路的粤语拼音是什么', 'answer': '东湖路（广东省广州市东湖路） ||| 粤语拼音 ||| dung1 wu4 lou6', 'relations': ['粤语拼音', '外文名', '中文名', '外文名'], 'tag': 'O'}
# {'id': 1984, 'question': '请问普贤警众偈表现了什么啊？', 'answer': '普贤警众偈 ||| 体现 ||| 佛教提倡精进的理念', 'relations': ['中文名', '出处', '属性', '体现'], 'tag': 'O'}
# {'id': 1986, 'question': '22A型客车是生产日期是什么时候', 'answer': '22A型客车 ||| 生产年份 ||| 1982年—1985年', 'relations': ['外文名', '型号', '生产年份', '生产厂商', '中文名'], 'tag': 'O'}
# {'id': 1987, 'question': '你知道6220c有多大运行内存吗', 'answer': '6220c ||| 运行内存 ||| 256MB ROM+128MB RAM', 'relations': ['运行内存', '中文名', '上市时间', '手机外形'], 'tag': 'O'}
# {'id': 1988, 'question': '请问南方银行是在哪里创立的？', 'answer': '南方银行 ||| 创立地点 ||| 委内瑞拉玛格丽塔岛', 'relations': ['参与国家', '中文名', '启动资金', '创立地点', '动议国家', '动议时期'], 'tag': 'O'}
# {'id': 1989, 'question': '你知道Channel Cookies是哪个公司出版的吗', 'answer': 'Channel Cookies ||| 出版公司 ||| 金牌大风', 'relations': ['演唱歌手', '产品', '外文名', '出版公司'], 'tag': 'O'}
# {'id': 1990, 'question': '山羊角树属属于引种吗？', 'answer': '山羊角树属 ||| 引种状况 ||| 非引种', 'relations': ['科', '引种状况', '拉丁学名', '中文名', '门', '界'], 'tag': 'O'}
# {'id': 1991, 'question': 'A-29“超级巨嘴鸟”有多大功率啊', 'answer': 'A-29“超级巨嘴鸟” ||| 功率 ||| 高达1193千瓦', 'relations': ['开发公司', '试飞时间', '功率', '外挂重量', '失速速度', '飞行时间', '中文名', '外文名', '发动机', '挂点', '使用国', '类型'], 'tag': 'O'}
# {'id': 1993, 'question': '1·25土耳其地震有多少震级？', 'answer': '1·25土耳其地震 ||| 震级 ||| 6.8级', 'relations': ['震级', '震源深度', '发生地点', '发生时间', '伤亡情况', '中文名'], 'tag': 'O'}
# {'id': 1995, 'question': '你知道1998特大洪水造成了什么经济损失吗', 'answer': '1998特大洪水 ||| 经济损失 ||| 2550.9亿元', 'relations': ['受灾面积', '外文名', '伤亡', '发生时间', '经济损失', '发生地点', '中文名', '受灾人口'], 'tag': 'O'}
# {'id': 1996, 'question': '你知道丰城公主的侄子是哪个吗', 'answer': '丰城公主 ||| 侄子 ||| 南唐后主李煜', 'relations': ['父亲', '所处时代', '侄子', '本名', '本名', '民族族群', '别名', '别称', '兄弟'], 'tag': 'O'}
# {'id': 1999, 'question': '宪法号博物馆位于哪里？', 'answer': '宪法号博物馆 ||| 展馆位置 ||| 美国马萨诸塞州查尔斯顿', 'relations': ['展馆名称', '展馆位置', '展馆主题', '外文名'], 'tag': 'O'}

# %%
O_count
# Out:
# 994

# %%
len(ner_examples2)
# Out:
# 2000

# %%
ner_examples2[:100]
# Out:
# [{'id': 0,
#   'question': '你知道长江武汉航道局管多少个地方吗？',
#   'answer': '长江武汉航道局 ||| 管辖 ||| 715.2公里',
#   'relations': ['职责', '中文名', '维护管理', '管辖'],
#   'tag': 'O'},
#  {'id': 1,
#   'question': '东瓯王发生的主要事件是什么？',
#   'answer': '东瓯王 ||| 主要事件 ||| 抗秦反秦，助汉击楚。',
#   'relations': ['主要事件', '中文名', '所属地', '姓氏', '东瓯王后', '代表人物'],
#   'tag': 'O'},
#  {'id': 2,
#   'question': '山西省铸造新工艺工程技术研究中心是什么的管辖的啊？',
#   'answer': '山西省铸造新工艺工程技术研究中心 ||| 机构类型 ||| 研究开发机构',
#   'relations': ['机构类型', '隶属', '研究项目', '中文名'],
#   'tag': 'O'},
#  {'id': 3,
#   'question': '你知道谁是丘堤的儿媳吗',
#   'answer': '丘堤 ||| 儿媳 ||| 籍虹',
#   'relations': ['出生日期',
#    '孙女',
#    '中文名',
#    '出生地',
#    '儿子',
#    '别名',
#    '主要成就',
#    '逝世日期',
#    '丈夫',
#    '儿媳'],
#   'tag': '人名'},
#  {'id': 4,
#   'question': '国民军参与过什么战争？',
#   'answer': '国民军 ||| 参与战争 ||| 直奉战争、北伐战争、中原大战、抗日战争',
#   'relations': ['外文名',
#    '别名',
#    '所属派系',
#    '改编时间',
#    '首领',
#    '中文名',
#    '主要将领',
#    '参与战争',
#    '外文名',
#    '领袖',
#    '分化之前'],
#   'tag': 'O'},
#  {'id': 5,
#   'question': '你知道诺基亚lumia1320的主屏尺寸是多少吗？',
#   'answer': '诺基亚lumia1320 ||| 主屏尺寸 ||| 6英寸',
#   'relations': ['主屏尺寸', '中文名', '型号', '品牌', '电池容量', '核心数', '代号', '像素', '外文名'],
#   'tag': 'O'},
#  {'id': 6,
#   'question': '你什么时候参加的执业兽医资格考试啊？',
#   'answer': '执业兽医资格考试 ||| 考试时间 ||| 10月',
#   'relations': ['实质', '外文名', '中文名', '分类', '考试时间'],
#   'tag': 'O'},
#  {'id': 7,
#   'question': '你知道2007年度北京流行音乐典礼是哪种类型的奖项吗',
#   'answer': '2007年度北京流行音乐典礼 ||| 奖项类型 ||| 音乐类奖项',
#   'relations': ['中文名', '奖项地区', '奖项类型', '别名'],
#   'tag': 'O'},
#  {'id': 8,
#   'question': 'BOT的总价要多少钱',
#   'answer': 'BOT（dota游戏中飞鞋的简称。） ||| 总价 ||| 2450',
#   'relations': ['配件', '卷轴价格', '中文名', '总价'],
#   'tag': 'O'},
#  {'id': 9,
#   'question': '你知道泰山极顶的作家是谁啊？',
#   'answer': '泰山极顶 ||| 作家 ||| 杨朔',
#   'relations': ['类别', '中文名', '作家', '主要描写'],
#   'tag': 'O'},
#  {'id': 10,
#   'question': '.org的注册机构是什么',
#   'answer': '.org ||| 注册机构 ||| VeriSign等',
#   'relations': ['外文名', '注册机构', '性质', '属性', '适用', '全称', '域名数量', '释义'],
#   'tag': 'O'},
#  {'id': 11,
#   'question': '我想知道法国斗牛犬有什么特点？',
#   'answer': '法国斗牛犬 ||| 形态特征 ||| 骨骼沉重，背毛平滑',
#   'relations': ['身高',
#    '亚门',
#    '原产地',
#    '科',
#    '用途',
#    '亚纲',
#    '体重',
#    '界',
#    '英文名',
#    '外文名',
#    '体重',
#    '门',
#    '目',
#    '身高',
#    '中文学名',
#    '种',
#    '亚目',
#    '纲',
#    '形态特征'],
#   'tag': '人名'},
#  {'id': 12,
#   'question': '请问七朵水仙花的作者是谁？',
#   'answer': '七朵水仙花 ||| 作家 ||| 金河仁',
#   'relations': ['中文名', '外文名', '七朵水仙花', '作家'],
#   'tag': 'O'},
#  {'id': 13,
#   'question': '你知道皖系军阀参与了什么战争？',
#   'answer': '皖系军阀 ||| 参与战争 ||| 直皖战争、江浙战争',
#   'relations': ['参与战争', '中文名', '势力范围', '首领', '外文名', '主要人物', '主要将领'],
#   'tag': 'O'},
#  {'id': 14,
#   'question': '信号与系统分析什么时候印刷的？',
#   'answer': '信号与系统分析（2012年清华大学出版社出版的图书） ||| 印刷日期 ||| 2016.01.27',
#   'relations': ['书名',
#    '出版时间',
#    '定价',
#    'ISBN',
#    '出版社',
#    '印次',
#    '印刷日期',
#    '出版时间',
#    'ISBN',
#    '定价',
#    '作者',
#    '作者'],
#   'tag': '书籍'},
#  {'id': 15,
#   'question': '请问设计成本控制是什么意思？',
#   'answer': '设计成本控制 ||| 阐述 ||| 生产而事先测算的产品成本',
#   'relations': ['中文名', '类别', '阐述', '相关'],
#   'tag': 'O'},
#  {'id': 16,
#   'question': '广东省预防青少年犯罪研究会由哪个单位发起？',
#   'answer': '广东省预防青少年犯罪研究会 ||| 发起单位 ||| 团省委、省法院、省公安厅等',
#   'relations': ['成立时间', '中文名', '业务主管单位', '发起单位'],
#   'tag': '组织机构'},
#  {'id': 17,
#   'question': '义安公主有侄女吗，叫什么啊',
#   'answer': '义安公主 ||| 侄女 ||| 千金公主、清都公主等',
#   'relations': ['父親',
#    '丈夫',
#    '别称',
#    '外甥女',
#    '侄女',
#    '侄女',
#    '兄弟',
#    '民族族群',
#    '出生地',
#    '姐妹',
#    '外甥女',
#    '本名',
#    '所处时代',
#    '别名'],
#   'tag': 'O'},
#  {'id': 18,
#   'question': '请问你好台湾网在哪里办公？',
#   'answer': '你好台湾网 ||| 办公地点 ||| 央广新媒体大厦',
#   'relations': ['外文名',
#    '成立时间',
#    '员工数',
#    '成立时间',
#    '公司名称',
#    '总部地点',
#    '员工数',
#    '公司类型',
#    '外文名称',
#    '经营范围',
#    '公司口号',
#    '办公地点',
#    '公司性质'],
#   'tag': '组织机构'},
#  {'id': 19,
#   'question': '谁能告诉我半屏岛都管些什么方面的事情？',
#   'answer': '半屏岛 ||| 管辖 ||| 东屏镇政府',
#   'relations': ['中文名', '岸线总长', '面积', '位于', '管辖'],
#   'tag': '地名'},
#  {'id': 20,
#   'question': '分众传媒主营一些什么业务？',
#   'answer': '分众传媒 ||| 主营业务 ||| 媒体广告业务。',
#   'relations': ['法人',
#    '外文名',
#    '法人',
#    '中文名',
#    '主营业务',
#    '股票代码',
#    '总部地点',
#    '创始人',
#    '成立时间',
#    '公司性质'],
#   'tag': '组织机构'},
#  {'id': 21,
#   'question': '2005年度北京流行音乐典礼是什么类型的奖？',
#   'answer': '2005年度北京流行音乐典礼 ||| 奖项类型 ||| 音乐类奖项',
#   'relations': ['中文名', '奖项地区', '奖项类型', '别名'],
#   'tag': 'O'},
#  {'id': 22,
#   'question': '七宝有哪些伙伴',
#   'answer': '七宝（日本漫画《犬夜叉》中的人物） ||| 伙伴 ||| 戈薇，犬夜叉，珊瑚，弥勒，云母',
#   'relations': ['登场作品',
#    '年龄',
#    '种族',
#    '配音',
#    '饰演',
#    '伙伴',
#    '别名',
#    '性别',
#    '外文名',
#    '中文名'],
#   'tag': '人名'},
#  {'id': 23,
#   'question': '量子力学是什么时候印刷的有人知道吗？',
#   'answer': '量子力学（2014年清华大学出版社出版的图书） ||| 印刷日期 ||| 2014—5-9',
#   'relations': ['装帧', '印刷日期', '作者', '书名', '出版社', 'ISBN', '定价'],
#   'tag': '书籍'},
#  {'id': 24,
#   'question': '万贵妃有什么历史原型吗',
#   'answer': '万贵妃（总票房5.7亿3D武侠巨制《龙门飞甲》中的角色） ||| 历史原型 ||| 明宪宗最宠爱的一位后妃',
#   'relations': ['来源',
#    '性格',
#    '合作演员',
#    '历史原型',
#    '饰演者',
#    '中文名',
#    '导演',
#    '亲信',
#    '性别',
#    '原名'],
#   'tag': '人名'},
#  {'id': 25,
#   'question': '4-4-2是什么时候流行的',
#   'answer': '4-4-2 ||| 流行时间 ||| 1966年',
#   'relations': ['代表球队', '类别', '中文名', '流行时间', '外文名'],
#   'tag': 'O'},
#  {'id': 26,
#   'question': '请问巴西海盆东西宽多少？',
#   'answer': '巴西海盆 ||| 东西宽 ||| 2000-2500公里',
#   'relations': ['外文名', '中文名', '南北长', '位于', '东西宽'],
#   'tag': 'O'},
#  {'id': 27,
#   'question': '请问九女泉的水有多深？',
#   'answer': '九女泉 ||| 水深 ||| 2米',
#   'relations': ['东与', '水深', '位于', '中文名'],
#   'tag': 'O'},
#  {'id': 28,
#   'question': '上海公交173路的日均客运量多少',
#   'answer': '上海公交173路 ||| 日均客运量 ||| 0.6 万人次',
#   'relations': ['车站数量',
#    '外文名',
#    '公交类型',
#    '线网长度',
#    '中文名',
#    '使用过的车型',
#    '始发站',
#    '日最高客运量',
#    '运营机构',
#    '终点站',
#    '运营线路',
#    '报站语言',
#    '车队规模',
#    '车票价格',
#    '可换乘',
#    '日均客运量'],
#   'tag': 'O'},
#  {'id': 29,
#   'question': '不伦瑞克的著名的大学有哪些',
#   'answer': '不伦瑞克（德国中北部城市） ||| 著名高校 ||| 布伦瑞克工业大学',
#   'relations': ['人口',
#    '所属国家',
#    '著名高校',
#    '中文名',
#    '人口数量',
#    '所属地区',
#    '外文名称',
#    '地理位置',
#    '国家',
#    '外文名',
#    '中文名称'],
#   'tag': '地名'},
#  {'id': 30,
#   'question': '久敬庄是什么类别的建筑？',
#   'answer': '久敬庄 ||| 建筑类别 ||| 板楼',
#   'relations': ['中文名称', '建筑类别', '开放时间', '房屋类型'],
#   'tag': 'O'},
#  {'id': 31,
#   'question': '你知道核心元素的游戏特征是什么类型的游戏吗？',
#   'answer': '核心元素 ||| 游戏特征 ||| 横版',
#   'relations': ['中文名', '游戏类型', '游戏特征', '实用平台', '外文名'],
#   'tag': '游戏'},
#  {'id': 32,
#   'question': '告诉我一下不死天皇的修为呗',
#   'answer': '不死天皇 ||| 修为 ||| 红尘仙',
#   'relations': ['出身',
#    '中文名',
#    '妻儿',
#    '信仰身',
#    '登场作品',
#    '身份',
#    '性别',
#    '极道帝兵',
#    '种族',
#    '修为'],
#   'tag': '人名'},
#  {'id': 33,
#   'question': '你知道丰县的县委书记是谁吗',
#   'answer': '丰县 ||| 县委书记 ||| 娄海',
#   'relations': ['现任领导',
#    '面积',
#    '地理位置',
#    '车牌代码',
#    '政府驻地',
#    '邮政区码',
#    '地区生产总值',
#    '人均GDP',
#    '人均GDP',
#    '外文名',
#    '政府驻地',
#    '下辖地区',
#    '历史名人',
#    '著名景点',
#    '人口',
#    '行政代码',
#    '人口',
#    '面积',
#    '中文名称',
#    '电话区号',
#    '气候条件',
#    '外文名称',
#    '县委书记',
#    '火车站',
#    '别名',
#    '行政区类别',
#    '方言',
#    '所属地区',
#    '机场',
#    'GDP',
#    '中文名'],
#   'tag': '地名'},
#  {'id': 34,
#   'question': '火凤凰是什么时候出生的？',
#   'answer': '火凤凰（港漫《神兵玄奇》《神兵玄奇贰》角色） ||| 出生年份 ||| 公元368年',
#   'relations': ['登场作品', '中文名', '出生年份', '别名', '性别'],
#   'tag': '人名'},
#  {'id': 35,
#   'question': 'AIK足球俱乐部是哪个联赛的',
#   'answer': 'AIK足球俱乐部 ||| 所属联赛 ||| 瑞典足球超级联赛',
#   'relations': ['创办时间', '运动项目', '所属联赛', '创办地点', '外文名', '中文名'],
#   'tag': '组织机构'},
#  {'id': 36,
#   'question': '1185年的主要事件是什么？',
#   'answer': '1185年 ||| 主要事件 ||| 大定病卒',
#   'relations': ['中文名', '主要事件', '又名', '别名'],
#   'tag': 'O'},
#  {'id': 37,
#   'question': '请告诉我107的罗马数字',
#   'answer': '107 ||| 罗马数字 ||| CVII',
#   'relations': ['二进制',
#    '八进制',
#    '倒数循环节',
#    '大写',
#    '四进制',
#    '中文名',
#    '十二进制',
#    '三进制',
#    '十六进制',
#    '罗马数字'],
#   'tag': 'O'},
#  {'id': 38,
#   'question': '告诉我上官瑞谦的女友是谁',
#   'answer': '上官瑞谦 ||| 女友 ||| 小渔',
#   'relations': ['年龄',
#    '别名',
#    '身高',
#    '中文名',
#    '女友',
#    '身高',
#    '体重',
#    '擅长',
#    '饰演',
#    '性别',
#    '体重',
#    '登场作品',
#    '性格',
#    '好友',
#    '职业',
#    '配音',
#    '毕业院校',
#    '其他名称'],
#   'tag': '人名'},
#  {'id': 39,
#   'question': '你知道阋神星的逃逸速度是多少吗？',
#   'answer': '阋神星 ||| 逃逸速度 ||| 1.38 km/s(±0.01)',
#   'relations': ['平近点角',
#    '别名',
#    '自转周期',
#    '质量',
#    '质量',
#    '升交点经度',
#    '表面温度',
#    '视星等',
#    '表面温度',
#    '公转周期',
#    '别称',
#    '分类',
#    '发现者',
#    '发现时间',
#    '离心率',
#    '半长轴',
#    '直径',
#    '离心率',
#    '绝对星等',
#    '半长轴',
#    '逃逸速度',
#    '中文名',
#    '发现时间',
#    '发现者',
#    '平均密度',
#    '反照率',
#    '轨道倾角',
#    '别名',
#    '直径',
#    '发现者',
#    '分类',
#    '外文名'],
#   'tag': 'O'},
#  {'id': 40,
#   'question': '七里河区有哪些有名的大学',
#   'answer': '七里河区 ||| 著名高校 ||| 兰州理工大学',
#   'relations': ['人口',
#    '地区生产总值',
#    '邮政区码',
#    '所属地区',
#    '面积',
#    '下辖地区',
#    '邮政区码',
#    '政府驻地',
#    '著名景点',
#    '中文名称',
#    '外文名',
#    '火车站',
#    '行政区类别',
#    '电话区号',
#    '车牌代码',
#    '下辖地区',
#    '气候条件',
#    '方言',
#    '著名高校',
#    '机场',
#    '人口',
#    '汽车站',
#    '中文名',
#    '面积',
#    '地理位置'],
#   'tag': '组织机构'},
#  {'id': 41,
#   'question': '乌拉圭国家男子足球队的FIFA排名是什么',
#   'answer': '乌拉圭国家男子足球队 ||| FIFA排名 ||| 第6位（2020年9月17日）',
#   'relations': ['中文队名',
#    '角逐赛事',
#    '成立时间',
#    '所属地区',
#    'FIFA排名',
#    '知名人物',
#    'FIFA排名',
#    '主场馆',
#    '拥有者',
#    '中文名',
#    '外文名',
#    '出场最多球员',
#    '主要荣誉',
#    '进球最多球员',
#    '主场馆',
#    '现任队长',
#    'FIFA代码',
#    '知名人物',
#    '出场最多球员',
#    '进球最多球员',
#    '外文队名',
#    '运动项目',
#    '现任主教练'],
#   'tag': '组织机构'},
#  {'id': 42,
#   'question': '严韵遥的养母是谁',
#   'answer': '严韵遥 ||| 养母 ||| 严玉霞',
#   'relations': ['外文名',
#    '中文名',
#    '爱人',
#    '配音',
#    '母亲',
#    '饰演',
#    '养母',
#    '其他名称',
#    '妹妹',
#    '性别',
#    '登场作品',
#    '父亲'],
#   'tag': '人名'},
#  {'id': 43,
#   'question': '煮羊肉具有什么营养价值？',
#   'answer': '煮羊肉 ||| 营养价值 ||| 可以增加人体热量抵御寒冷',
#   'relations': ['吃羊肉', '营养价值', '中文名', '食材', '属于', '功效'],
#   'tag': 'O'},
#  {'id': 44,
#   'question': '谁是《王子外出赚钱中》的作者？',
#   'answer': '王子外出赚钱中 ||| 漫画作者 ||| サマミヤアカザ / 岩城广海',
#   'relations': ['漫画类型', '漫画作者', '中文名', '上架日期'],
#   'tag': 'O'},
#  {'id': 45,
#   'question': '谁知道万年飘香的执行导演啊',
#   'answer': '万年飘香 ||| 执行导演 ||| 靳鑫鹏',
#   'relations': ['制片地区',
#    '出品公司',
#    '上映时间',
#    '编剧',
#    '制片人',
#    '导演',
#    '联合摄制',
#    '联合摄制',
#    '联合摄制',
#    '色彩',
#    '主演',
#    '出品时间',
#    '执行导演',
#    '中文名',
#    '主演',
#    '类型',
#    '对白语言',
#    '片长',
#    '主题曲',
#    '制片地区',
#    '联合摄制'],
#   'tag': '娱乐，影视节目'},
#  {'id': 46,
#   'question': '于伟的执业证号是多少',
#   'answer': '于伟（安徽事茂律师事务所律师） ||| 执业证号 ||| 安徽事茂律师事务所',
#   'relations': ['中文名', '执业证号', '职业', '国籍'],
#   'tag': '人名'},
#  {'id': 47,
#   'question': '请问蕨粉有哪些营养成分？',
#   'answer': '蕨粉 ||| 营养成分 ||| 维生素C',
#   'relations': ['原料', '营养成分', '中文名', '食用功效：', '原料：', '营养成分：', '食用功效'],
#   'tag': 'O'},
#  {'id': 48,
#   'question': '东君草堂诗选的作品题材是什么',
#   'answer': '东君草堂诗选 ||| 作品题材 ||| 春夏秋冬',
#   'relations': ['出版社',
#    'ISBN',
#    '外文名',
#    '作品名称',
#    '作品题材',
#    '创作年代',
#    '作品体裁',
#    '售价',
#    '作者',
#    '作品出处'],
#   'tag': '书籍'},
#  {'id': 49,
#   'question': '三田佳子的长子是谁',
#   'answer': '三田佳子 ||| 长子 ||| 森宫隆',
#   'relations': ['经纪公司',
#    '职业',
#    '国籍',
#    '出生地',
#    '原名',
#    '别名',
#    '星座',
#    '丈夫',
#    '出生日期',
#    '身高',
#    '身高',
#    '长子',
#    '代表作品',
#    '外文名',
#    '中文名',
#    '血型'],
#   'tag': '人名'},
#  {'id': 50,
#   'question': '你知道夺子战争1997的片头曲是什么啊？',
#   'answer': '夺子战争1997 ||| 片头曲 ||| 陈升《风筝》',
#   'relations': ['片尾曲',
#    '出品地点',
#    '片头曲',
#    '类型',
#    '语言',
#    '制片地区',
#    '中文名',
#    '导演',
#    '最早播出时间',
#    '出品公司',
#    '集数'],
#   'tag': '娱乐，影视节目'},
#  {'id': 51,
#   'question': '你知道三家村的耕地面积多大吗',
#   'answer': '三家村（山西平遥县香乐乡下辖村） ||| 总耕地面积 ||| 2193亩',
#   'relations': ['行政区类别', '总耕地面积', '人口', '中文名称'],
#   'tag': 'O'},
#  {'id': 52,
#   'question': '请问上海交通大学苏州人工智能研究院的统一社会信用代码是什么',
#   'answer': '上海交通大学苏州人工智能研究院 ||| 统一社会信用代码 ||| 12320500MB0520380R',
#   'relations': ['中文名', '成立时间', '地址', '组织性质', '统一社会信用代码'],
#   'tag': '组织机构'},
#  {'id': 53,
#   'question': '请告诉我CP的本意是什么',
#   'answer': 'CP（人物配对CharacterPairing） ||| 本意 ||| 是指有恋爱关系的同人配对',
#   'relations': ['全称', '日文', '本意', '应用', '外文名', '中文名'],
#   'tag': 'O'},
#  {'id': 54,
#   'question': '七濑陆讨厌什么',
#   'answer': '七濑陆 ||| 讨厌 ||| 医院的味道',
#   'relations': ['别名',
#    '身高',
#    '配音',
#    '喜欢',
#    '其他名称',
#    '哥哥',
#    '中文名',
#    '讨厌',
#    '生日',
#    '代表色',
#    '年龄',
#    '性别',
#    '担当',
#    '登场作品',
#    '身高'],
#   'tag': '人名'},
#  {'id': 55,
#   'question': '胆绿素有哪些形态特征？',
#   'answer': '胆绿素 ||| 形态特征 ||| 深绿色片状或柱状结晶',
#   'relations': ['存在位置', '中文名', '外文名', '前体物质', '分类', '形态特征'],
#   'tag': 'O'},
#  {'id': 56,
#   'question': '要怎么获得8比特啊',
#   'answer': '8比特 ||| 获得方式 ||| 荣誉之路6000杯奖励',
#   'relations': ['登场作品', '普通攻击', '中文名', '类型', '性别', '获得方式'],
#   'tag': '人名'},
#  {'id': 57,
#   'question': '华中农业大学学术委员会属于哪所大学呢？',
#   'answer': '华中农业大学学术委员会 ||| 所属院校 ||| 华中农业大学',
#   'relations': ['所属院校', '中文名'],
#   'tag': 'O'},
#  {'id': 58,
#   'question': '和康居国有关的地理知识有哪些？',
#   'answer': '康居国 ||| 地理 ||| 西域三十六国之一',
#   'relations': ['位置', '灭亡时间', '地理', '建国时间', '中文名', '位置'],
#   'tag': 'O'},
#  {'id': 59,
#   'question': '你知道Ich Liebe Dich是哪个公司出版的吗',
#   'answer': 'Ich Liebe Dich（Andrea Bocelli演唱歌曲） ||| 出版公司 ||| 环球唱片',
#   'relations': ['发行时间',
#    '外文名称',
#    '编曲',
#    '所属专辑',
#    '歌曲原唱',
#    '谱曲',
#    '音乐风格',
#    '发行日期',
#    '填词',
#    '出版公司',
#    '歌曲语言',
#    '外文名'],
#   'tag': '音乐'},
#  {'id': 60,
#   'question': '藤山柳属属于引种吗？',
#   'answer': '藤山柳属 ||| 引种状况 ||| 非引种',
#   'relations': ['拉丁学名', '科', '引种状况', '界', '分布量', '中文名'],
#   'tag': 'O'},
#  {'id': 61,
#   'question': '你知道东方仗助的伙伴都有谁吗',
#   'answer': '东方仗助 ||| 伙伴 ||| 广濑康一、虹村亿泰、岸边露伴、矢安宫重清',
#   'relations': ['伙伴',
#    '体重',
#    '爱称',
#    '外文名',
#    '家庭住址',
#    '身高',
#    '性别',
#    '毕业院校',
#    '生日',
#    '国籍',
#    '星座',
#    '血型',
#    '声优',
#    '饰演',
#    '班级',
#    '代表作品',
#    '居住地',
#    '别名',
#    '登场作品',
#    '出生地',
#    '父母',
#    '配音',
#    '体重',
#    '年龄',
#    '外文名',
#    '身高',
#    '替身',
#    '职业',
#    '出生日期',
#    '中文名',
#    '别名',
#    '民族',
#    '口头禅'],
#   'tag': '人名'},
#  {'id': 62,
#   'question': '搜一下何清华有几遍论文',
#   'answer': '何清华（西南大学心理学部教授） ||| 发表论文数量 ||| 80篇（截至2019年7月）',
#   'relations': ['国籍', '专业方向', '中文名', '毕业院校', '发表论文数量', '出生地', '民族', '学位/学历'],
#   'tag': '人名'},
#  {'id': 63,
#   'question': '你知道中华人民共和国第一届全国人民代表大会第五次会议是什么时候开会吗？',
#   'answer': '中华人民共和国第一届全国人民代表大会第五次会议 ||| 会议时间 ||| 1958年2月1日',
#   'relations': ['主要议程', '中文名', '会议地点', '会议时间'],
#   'tag': 'O'},
#  {'id': 64,
#   'question': '1952年奥斯陆冬季奥运会的比赛时间是什么时候',
#   'answer': '1952年奥斯陆冬季奥运会 ||| 比赛时间 ||| 1952年2月14-1952年2月25日',
#   'relations': ['参赛运动员',
#    '参赛国和地区',
#    '外文名',
#    '比赛时间',
#    '下一届',
#    '中文名',
#    '主办国和城市',
#    '项目数',
#    '上一届'],
#   'tag': 'O'},
#  {'id': 65,
#   'question': '何家村的人均耕地面积是多少？',
#   'answer': '何家村（云南省会泽县新街回族乡何家村） ||| 人均耕地 ||| 0.54亩',
#   'relations': ['中文名',
#    '人均耕地',
#    '耕地面积',
#    '农作物',
#    '国土面积',
#    '国土面积',
#    '人均耕地',
#    '实质',
#    '耕地面积',
#    '地理位置',
#    '林地'],
#   'tag': '地名'},
#  {'id': 66,
#   'question': '再次飞升是从哪天开始创作的？',
#   'answer': '再次飞升 ||| 开始创作时间 ||| 2007年5月21日',
#   'relations': ['作品标签', '书名', '作者', '类别', '开始创作时间', '写作进程', '首发网站'],
#   'tag': '书籍'},
#  {'id': 67,
#   'question': '104的罗马数字是多少',
#   'answer': '104 ||| 罗马数字 ||| CIV',
#   'relations': ['三进制',
#    '因数分解',
#    '倒数循环节',
#    '中文名',
#    '八进制',
#    '十二进制',
#    '四进制',
#    '二进制',
#    '外文名',
#    '罗马数字',
#    '大写',
#    '十六进制'],
#   'tag': 'O'},
#  {'id': 68,
#   'question': 'Afilia Saga的旧名是什么',
#   'answer': 'Afilia Saga ||| 旧名 ||| AfiliaSagaEast',
#   'relations': ['中文名', '外文名', '旧名', '成立时间'],
#   'tag': '组织机构'},
#  {'id': 69,
#   'question': '第11届华盛顿影评人协会奖在哪个电影中获得最佳男主角？',
#   'answer': '第11届华盛顿影评人协会奖 ||| 最佳男主角 ||| 丹尼尔·戴·刘易斯《林肯》',
#   'relations': ['中文名', '最佳男主角', '最佳影片', '举办时间', '最佳导演'],
#   'tag': 'O'},
#  {'id': 70,
#   'question': '什么可以治疗疼痛病？',
#   'answer': '疼痛病 ||| 治疗 ||| 疼痛诊疗专科',
#   'relations': ['中文名', '发病原因', '治疗', '领域'],
#   'tag': 'O'},
#  {'id': 71,
#   'question': '康斯坦茨会议是什么时候？',
#   'answer': '康斯坦茨会议 ||| 会议时间 ||| 1414年至1418年',
#   'relations': ['会议时间', '地点', '中文名', '主要议题', '时间'],
#   'tag': 'O'},
#  {'id': 72,
#   'question': '甩尾需要哪些步骤？',
#   'answer': '甩尾（口袋妖怪技能） ||| 步骤 ||| 朝目标移动直到目标进入射程',
#   'relations': ['概述', '什么是甩尾', '中文名', '步骤'],
#   'tag': 'O'},
#  {'id': 73,
#   'question': '请问10·12宜兰地震的震源深度是多少',
#   'answer': '10·12宜兰地震 ||| 震源深度 ||| 9千米',
#   'relations': ['震源深度', '地震时间', '中文名', '地震位置', '地震震级'],
#   'tag': 'O'},
#  {'id': 74,
#   'question': '有哪些球队参加了1922年巴西美洲杯',
#   'answer': '1922年巴西美洲杯 ||| 参赛球队 ||| 巴拉圭、乌拉圭、巴西、阿根廷、智利',
#   'relations': ['亚军',
#    '届别',
#    '赛事类型',
#    '冠军',
#    '举办地',
#    '举办时间',
#    '参赛球队',
#    '中文名称',
#    '中文名'],
#   'tag': 'O'},
#  {'id': 75,
#   'question': '武宫正树师从于谁？',
#   'answer': '武宫正树 ||| 师从 ||| 初为田中三七一，后为木谷实',
#   'relations': ['中文名',
#    '主要成就',
#    '别名',
#    '主要成就',
#    '出生地',
#    '民族',
#    '主要成就',
#    '国籍',
#    '职业',
#    '主要成就',
#    '主要成就',
#    '出生地',
#    '出生日期',
#    '师从',
#    '段位',
#    '运动项目',
#    '外文名'],
#   'tag': '人名'},
#  {'id': 76,
#   'question': '你知道武定的起始地在哪吗？',
#   'answer': '武定（东魏孝静帝年号） ||| 起始 ||| 543年正月',
#   'relations': ['朝代', '历时', '性质', '起始', '中文名', '终止'],
#   'tag': 'O'},
#  {'id': 77,
#   'question': '请问湖北莲田食品开发有限公司的主营业务有哪些？',
#   'answer': '湖北莲田食品开发有限公司 ||| 主营业务 ||| 产销售农副产品',
#   'relations': ['公司名称', '主营业务', '企业事件', '公司类型'],
#   'tag': '组织机构'},
#  {'id': 78,
#   'question': '代庆成的医师级别是什么',
#   'answer': '代庆成 ||| 医师级别 ||| 执业医师',
#   'relations': ['医师级别', '执业地点', '国籍', '执业证书编码', '外文名', '民族', '中文名'],
#   'tag': '人名'},
#  {'id': 79,
#   'question': '文夕大火有多少人遇难？',
#   'answer': '文夕大火 ||| 死亡人数 ||| 30000余人',
#   'relations': ['经济损失', '发生时间', '死亡人数', '外文名', '发生地点', '中文名', '发生地点', '中日指挥官'],
#   'tag': 'O'},
#  {'id': 80,
#   'question': '中国人民武装警察部队海警总队属于什么机构的类型？',
#   'answer': '中国人民武装警察部队海警总队 ||| 机构类型 ||| 武警部队下属总队',
#   'relations': ['中文名',
#    '机构类型',
#    '海警局副局长',
#    '成立时间',
#    '外文名',
#    '海警局局长',
#    '职责',
#    '转隶时间',
#    '成立时间',
#    '直属机构',
#    '外文名',
#    '隶属部队'],
#   'tag': '组织机构'},
#  {'id': 81,
#   'question': '请问时间移民的印张是多少？',
#   'answer': '时间移民 ||| 印张 ||| 11',
#   'relations': ['书名',
#    '装帧',
#    '出版社',
#    '页数',
#    'ISBN',
#    '开本',
#    '类别',
#    '丛书',
#    '出版时间',
#    '出版时间',
#    '定价',
#    '定价',
#    '页数',
#    '作者',
#    '印张'],
#   'tag': '书籍'},
#  {'id': 82,
#   'question': 'N的养父是谁',
#   'answer': 'N（掌机游戏《宝可梦》人物） ||| 养父 ||| 魁奇思',
#   'relations': ['养父',
#    '外文名',
#    '登场作品',
#    '中文名',
#    '身高',
#    '别名',
#    '年龄',
#    '登场作品',
#    '配音',
#    '性别',
#    '朋友',
#    '身份'],
#   'tag': '人名'},
#  {'id': 83,
#   'question': '你知道元气娘一般都被指代成什么吗？',
#   'answer': '元气娘（ACGN界用语） ||| 指代 ||| 乐观充满希望，活泼又可爱女孩子',
#   'relations': ['类别', '指代', '使用者', '中文名'],
#   'tag': 'O'},
#  {'id': 84,
#   'question': '中空知美咲的就读学校是什么呢',
#   'answer': '中空知美咲 ||| 就读学校 ||| 东京武侦高中',
#   'relations': ['登场作品',
#    '就读学校',
#    '配音',
#    '喜欢',
#    '国家',
#    '班级',
#    '地区',
#    '中文名',
#    '性别',
#    '外文名'],
#   'tag': '人名'},
#  {'id': 85,
#   'question': '你知道烟火阑珊的作品风格属于什么系列吗？',
#   'answer': '烟火阑珊 ||| 作品风格 ||| 正剧',
#   'relations': ['连载状态',
#    '类型',
#    '作者',
#    '作品风格',
#    '全文字数',
#    '出版日期',
#    '中文名称',
#    '所属系列',
#    '中文名'],
#   'tag': '书籍'},
#  {'id': 86,
#   'question': '迹象展览是什么时候开幕的？',
#   'answer': '迹象（艺术展览） ||| 开幕时间 ||| 2021-03-05',
#   'relations': ['地点', '开幕时间', '中文名', '闭幕时间'],
#   'tag': 'O'},
#  {'id': 87,
#   'question': 'Tony Lee有什么荣誉',
#   'answer': 'Tony Lee ||| 个人荣誉 ||| “2014最具价值CTO”奖',
#   'relations': ['学位', '研究领域', '中文名', '职称', '毕业院校', '个人荣誉'],
#   'tag': '人名'},
#  {'id': 88,
#   'question': '七情六欲是从哪天开始创作的？',
#   'answer': '七情六欲（唯吾神音编写奇幻修真型小说） ||| 开始创作时间 ||| 2012年3月17日',
#   'relations': ['开始创作时间', '类别', '中文名', '作者'],
#   'tag': '书籍'},
#  {'id': 89,
#   'question': 'The Bravery的建馆时间是什么时候',
#   'answer': 'The Bravery（大无畏乐团） ||| 建馆时间 ||| 2003年',
#   'relations': ['建馆时间', '成立时间', '成立地点', '外文名', '中文名'],
#   'tag': '组织机构'},
#  {'id': 90,
#   'question': '手球的组织结构是什么啊？',
#   'answer': '手球（体育类竞技运动） ||| 组织机构 ||| 国际手球联合会、 亚洲手球联合会、中国手球协会',
#   'relations': ['代表人物', '组织机构', '类别', '起源地', '中文名', '起源时间', '外文名'],
#   'tag': 'O'},
#  {'id': 91,
#   'question': '谁知道Rong行销是哪个部门的',
#   'answer': 'Rong行销 ||| 隶属部门 ||| Rong融道（中国）',
#   'relations': ['隶属部门', '中文名', '性质', '企业类型'],
#   'tag': 'O'},
#  {'id': 92,
#   'question': '一探究竟的重播时间是什么时候的',
#   'answer': '一探究竟 ||| 重播时间 ||| 周六15:01',
#   'relations': ['播出频道', '首播时间', '节目目的', '重播时间', '外文名', '节目类型', '主持人', '中文名'],
#   'tag': '娱乐，影视节目'},
#  {'id': 93,
#   'question': 'B-36的飞行速度多少',
#   'answer': 'B-36 ||| 飞行速度 ||| 亚音速',
#   'relations': ['服役时间', '退役时间', '气动布局', '中文名', '外文名', '首飞时间', '飞行速度', '研发单位'],
#   'tag': 'O'},
#  {'id': 94,
#   'question': '三宝有哪些同僚啊',
#   'answer': '三宝（《后宫·如懿传》中如懿的心腹大太监） ||| 同僚 ||| 容珮、惢心、菱枝、芸枝等',
#   'relations': ['登场作品',
#    '登场作品',
#    '所属宫室',
#    '饰演',
#    '别名',
#    '同僚',
#    '性别',
#    '主子',
#    '中文名',
#    '身份',
#    '住所'],
#   'tag': '人名'},
#  {'id': 95,
#   'question': '请问SCP-CN-052的项目编号是多少？',
#   'answer': 'SCP-CN-052 ||| 项目编号 ||| SCP-CN-052',
#   'relations': ['项目编号', '项目等级', '中文名'],
#   'tag': 'O'},
#  {'id': 96,
#   'question': "你知道I'm Not Afraid版权属于谁吗",
#   'answer': "I'm Not Afraid（刘忻2015年发行单曲EP收录歌曲） ||| 版权所有 ||| 天娱音乐",
#   'relations': ['音乐风格',
#    '填词',
#    '版权所有',
#    '外文名',
#    '所属专辑',
#    '中文名称',
#    '外文名称',
#    '歌曲原唱',
#    '歌曲原唱',
#    '歌曲语言',
#    '中文名',
#    '歌曲时长',
#    '歌曲语言',
#    '发行时间',
#    '谱曲',
#    '填词',
#    '音乐风格'],
#   'tag': '音乐'},
#  {'id': 97,
#   'question': '一定要幸福的备案地在哪',
#   'answer': '一定要幸福（2016年中国拍摄影片） ||| 备案地 ||| 北京市',
#   'relations': ['中文名', '编剧', '备案地', '备案立项号'],
#   'tag': '娱乐，影视节目'},
#  {'id': 98,
#   'question': '南澳岛的陆地面积达到多少？',
#   'answer': '南澳岛（南海岛屿） ||| 陆地面积 ||| 113.81平方公里',
#   'relations': ['中文名',
#    '岛上景区',
#    '最佳游玩季节',
#    '著名景点',
#    '地理位置',
#    '所属地区',
#    '别名',
#    '开放时间',
#    '陆地面积',
#    '常住人口',
#    '著名景点',
#    '建议游玩时长',
#    '外文名',
#    '海域面积',
#    '岛上景区',
#    '建议游玩时长',
#    '对外交通',
#    '门票价格'],
#   'tag': '地名'},
#  {'id': 99,
#   'question': '战略实施的实现意味着什么？',
#   'answer': '战略实施 ||| 实现 ||| 企业战略目标',
#   'relations': ['别名', '实现', '又名', '释义', '中文名'],
#   'tag': 'O'}]
